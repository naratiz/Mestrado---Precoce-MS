# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#determinar se uma coluna / variável é numérico ou não
from pandas.api.types import is_string_dtype, is_numeric_dtype

# %%
df = pd.read_csv('../dados/dadosCompletos.csv', sep=';')

# %%
pd.set_option('display.max_columns',999)
pd.set_option("display.max_rows", 999)

# %%
df.sample(5)
# Out:
#          id_animal estabelecimento_municipio data_abate  \
# 889877      889878                  MARACAJU  30OCT2018
# 450606      450607                     COXIM  02APR2018
# 881282      881283                PONTA PORA  26OCT2018
# 1015292    1015293                PONTA PORA  12DEC2018
# 395302      395303             LAGUNA CARAPA  15FEB2018
#
#          estabelecimento_identificador  identificador_lote     tipificacao  \
# 889877                            5309               72206           famea
# 450606                            5463               41847           famea
# 881282                            7722               71755  macho castrado
# 1015292                           1367               78360  macho castrado
# 395302                            1135               34942           famea
#
#              maturidade                                         acabamento  \
# 889877   Dente de leite  gordura mediana - acima de 3 a ata 6 mm de esp...
# 450606      Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
# 881282    Quatro dentes                            magra - gordura ausente
# 1015292     Dois dentes            gordura escassa - 1 a 3 mm de espessura
# 395302      Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
#
#           peso          motivo_desclassificacao  q_classificacao_estabel  \
# 889877   195.0                     CLASSIFICADO                     30.0
# 450606   220.8                     CLASSIFICADO                     21.0
# 881282   190.0  DESCLASSIFICADO PELO ACABAMENTO                     21.0
# 1015292  278.5                     CLASSIFICADO                     21.0
# 395302   196.8                     CLASSIFICADO                     26.0
#
#         q_outros_incentiv q_pratica_recuperacao_pa q_fertiirrigacao q_ilp  \
# 889877                NÃO                      SIM              NÃO   SIM
# 450606                NÃO                      NÃO              NÃO   NÃO
# 881282                NÃO                      NÃO              NÃO   NÃO
# 1015292               NÃO                      SIM              NÃO   SIM
# 395302                NÃO                      SIM              NÃO   SIM
#
#         q_ilpf q_ifp q_fabrica_racao q_identificacao_individual  \
# 889877     NÃO   NÃO             SIM                        SIM
# 450606     NÃO   NÃO             NÃO                        NÃO
# 881282     NÃO   NÃO             SIM                        NÃO
# 1015292    NÃO   NÃO             SIM                        NÃO
# 395302     NÃO   NÃO             SIM                        SIM
#
#         q_regua_manejo q_bpa q_aliancas_mercadolog q_qual_alianca  \
# 889877             SIM   NÃO                   SIM          ASPNP
# 450606             SIM   NÃO                   NÃO            NaN
# 881282             SIM   NÃO                   NÃO            NaN
# 1015292            SIM   NÃO                   NÃO            NaN
# 395302             SIM   NÃO                   NÃO            NaN
#
#         q_cobertura_vegetal_80_area q_erosaoo_sulco_20_area q_sisbov  \
# 889877                          SIM                     NÃO      NÃO
# 450606                          SIM                     NÃO      NÃO
# 881282                          SIM                     NÃO      NÃO
# 1015292                         SIM                     NÃO      NÃO
# 395302                          SIM                     NÃO      SIM
#
#         q_lista_trace    data12m     data6m     data3m     data1m     data7d  \
# 889877            NaN  29OCT2017  30APR2018  29JUL2018  29SEP2018  22OCT2018
# 450606            NaN  01APR2017  01OCT2017  30DEC2017  02MAR2018  25MAR2018
# 881282            NaN  25OCT2017  26APR2018  25JUL2018  25SEP2018  18OCT2018
# 1015292           NaN  11DEC2017  12JUN2018  10SEP2018  11NOV2018  04DEC2018
# 450606            138.75           1.0000               0.0           1.0000
# 881282            144.00           0.7778               0.0           0.7500
# 1015292           144.71           1.0000               0.0           0.8750
# 395302            138.62           1.0000               0.0           1.0000
#
#          cnt1m_cl_ituinst  cnt3m_cl_itumax  cnt3m_cl_ituinst  cnt6m_cl_itumax  \
# 889877              0.000           0.7021            0.0000           0.6902
# 450606              0.375           0.9787            0.2021           0.9837
# 881282              0.000           0.5319            0.0000           0.4783
# 1015292             0.000           0.7979            0.0000           0.6033
# 395302              0.000           0.9302            0.0000           0.8977
#
#          cnt6m_cl_ituinst  cnt12m_cl_itumax  cnt12m_cl_ituinst   ano  \
# 889877             0.0000            0.8174             0.0354  2018
# 450606             0.1304            0.9510             0.1008  2018
# 881282             0.0000            0.6703             0.0000  2018
# 1015292            0.0000            0.6676             0.0000  2018
# 395302             0.0057            0.7688             0.0084  2018
#
#         categoria  classificacao
# 889877        AAA              1
# 450606         AA              1
# 881282          D              0
# 1015292        BB              1
# 395302         AA              1

# %% [markdown]
# ## Dados Faltantes

# %%
#quais missing values e quantos são, qual feature está com mais NaN.
df.isnull().sum().sort_values(ascending=False)
# Out:
# q_qual_alianca                   717338
# q_lista_trace                    571523
# q_erosaoo_sulco_20_area          231491
# q_cobertura_vegetal_80_area      231491
# tot7d_chuva                      125666
# tot1m_chuva                       51263
# q_sisbov                          49296
# q_aliancas_mercadolog             49296
# q_bpa                             49296
# q_classificacao_estabel           49296
# q_outros_incentiv                 49296
# q_pratica_recuperacao_pa          49296
# q_regua_manejo                    49296
# q_identificacao_individual        49296
# q_fabrica_racao                   49296
# cnt7d_cl_itumax                   46570
# cnt7d_cl_ituinst                  46519
# med7d_tempmin                     46441
# med7d_tempmax                     46441
# med7d_tempinst                    45274
# med7d_umidmin                     45223
# med7d_umidinst                    44285
# med12m_ndvi                       44204
# med12m_num_pixels                 44204
# med3m_num_pixels                  44204
# med7d_ndvi                        44204
# med7d_evi                         44204
# med1m_num_pixels                  44204
# med1m_ndvi                        44204
# med1m_evi                         44204
# med7d_num_pixels                  44204
# med12m_evi                        44204
# med6m_evi                         44204
# med6m_ndvi                        44204
# med6m_num_pixels                  44204
# med3m_evi                         44204
# med3m_ndvi                        44204
# med7d_umidmax                     44129
# med7d_velventomax                 43218
# cnt1m_cl_itumax                   28155
# med1m_tempmin                     28155
# med1m_tempmax                     28155
# cnt1m_cl_ituinst                  27986
# med1m_tempinst                    27986
# med1m_umidmin                     22361
# med1m_umidmax                     22361
# med1m_velventomax                 22192
# med1m_umidinst                    22192
# tot3m_chuva                       17344
# med3m_tempmax                      5249
# med3m_tempmin                      5249
# med3m_tempinst                     5249
# cnt3m_cl_ituinst                   5249
# cnt3m_cl_itumax                    5249
# med3m_velventomax                   180
# med3m_umidmax                       180
# med3m_umidinst                      180
# med3m_umidmin                       180
# tot12m_chuva                          0
# med6m_prer_soja                       0
# med6m_prer_boi                        0
# med6m_formitumax                      0
# med6m_formituinst                     0
# med6m_prer_milho                      0
# id_animal                             0
# med12m_tempinst                       0
# med12m_tempmax                        0
# categoria                             0
# ano                                   0
# cnt12m_cl_ituinst                     0
# cnt12m_cl_itumax                      0
# cnt6m_cl_ituinst                      0
# cnt6m_cl_itumax                       0
# med12m_prer_boi                       0
# med12m_prer_milho                     0
# med12m_prer_soja                      0
# med12m_formitumax                     0
# med6m_umidmin                         0
# med12m_formituinst                    0
# med12m_velventomax                    0
# med12m_umidmin                        0
# med12m_umidmax                        0
# med12m_umidinst                       0
# med12m_tempmin                        0
# med6m_velventomax                     0
# med1m_prer_milho                      0
# med6m_umidmax                         0
# q_fertiirrigacao                      0
# data1m                                0
# data3m                                0
# data6m                                0
# data12m                               0
# q_ifp                                 0
# q_ilpf                                0
# q_ilp                                 0
# motivo_desclassificacao               0
# med7d_formituinst                     0
# peso                                  0
# acabamento                            0
# maturidade                            0
# tipificacao                           0
# identificador_lote                    0
# estabelecimento_identificador         0
# data_abate                            0
# data7d                                0
# med7d_formitumax                      0
# med6m_umidinst                        0
# med3m_formitumax                      0
# med6m_tempmin                         0
# med6m_tempmax                         0
# med6m_tempinst                        0
# tot6m_chuva                           0
# med3m_prer_boi                        0
# med3m_prer_milho                      0
# med3m_prer_soja                       0
# med3m_formituinst                     0
# med7d_prer_soja                       0
# med1m_prer_boi                        0
# estabelecimento_municipio             0
# med1m_prer_soja                       0
# med1m_formitumax                      0
# med1m_formituinst                     0
# med7d_prer_boi                        0
# med7d_prer_milho                      0
# classificacao                         0
# dtype: int64

# %%
#Calcular a porcentagem de valores ausentes.

# %%
round(df.isnull().mean() * 100,2).sort_values(ascending=False)
# Out:
# q_qual_alianca                   67.58
# q_lista_trace                    53.84
# q_cobertura_vegetal_80_area      21.81
# q_erosaoo_sulco_20_area          21.81
# tot7d_chuva                      11.84
# tot1m_chuva                       4.83
# q_sisbov                          4.64
# q_identificacao_individual        4.64
# q_classificacao_estabel           4.64
# q_outros_incentiv                 4.64
# q_pratica_recuperacao_pa          4.64
# q_aliancas_mercadolog             4.64
# q_bpa                             4.64
# q_regua_manejo                    4.64
# q_fabrica_racao                   4.64
# cnt7d_cl_itumax                   4.39
# med7d_tempmin                     4.38
# med7d_tempmax                     4.38
# cnt7d_cl_ituinst                  4.38
# med7d_tempinst                    4.27
# med7d_umidmin                     4.26
# med7d_umidinst                    4.17
# med12m_ndvi                       4.16
# med7d_umidmax                     4.16
# med12m_num_pixels                 4.16
# med3m_num_pixels                  4.16
# med7d_ndvi                        4.16
# med7d_evi                         4.16
# med1m_num_pixels                  4.16
# med1m_ndvi                        4.16
# med1m_evi                         4.16
# med7d_num_pixels                  4.16
# med6m_ndvi                        4.16
# med12m_evi                        4.16
# med3m_ndvi                        4.16
# med3m_evi                         4.16
# med6m_num_pixels                  4.16
# med6m_evi                         4.16
# med7d_velventomax                 4.07
# cnt1m_cl_itumax                   2.65
# med1m_tempmin                     2.65
# med1m_tempmax                     2.65
# cnt1m_cl_ituinst                  2.64
# med1m_tempinst                    2.64
# med1m_umidmin                     2.11
# med1m_umidmax                     2.11
# med1m_velventomax                 2.09
# med1m_umidinst                    2.09
# tot3m_chuva                       1.63
# cnt3m_cl_ituinst                  0.49
# cnt3m_cl_itumax                   0.49
# med3m_tempmin                     0.49
# med3m_tempmax                     0.49
# med3m_tempinst                    0.49
# med3m_umidmin                     0.02
# med3m_velventomax                 0.02
# med3m_umidmax                     0.02
# med3m_umidinst                    0.02
# tot12m_chuva                      0.00
# med6m_prer_soja                   0.00
# med6m_prer_boi                    0.00
# med6m_prer_milho                  0.00
# med6m_formitumax                  0.00
# med6m_formituinst                 0.00
# id_animal                         0.00
# med12m_tempinst                   0.00
# med12m_tempmax                    0.00
# categoria                         0.00
# ano                               0.00
# cnt12m_cl_ituinst                 0.00
# cnt12m_cl_itumax                  0.00
# cnt6m_cl_ituinst                  0.00
# cnt6m_cl_itumax                   0.00
# med12m_prer_boi                   0.00
# med12m_prer_milho                 0.00
# med12m_prer_soja                  0.00
# med12m_formitumax                 0.00
# med6m_umidmin                     0.00
# med12m_formituinst                0.00
# med12m_velventomax                0.00
# med12m_umidmin                    0.00
# med12m_umidmax                    0.00
# med12m_umidinst                   0.00
# med12m_tempmin                    0.00
# med6m_velventomax                 0.00
# med1m_prer_milho                  0.00
# med6m_umidmax                     0.00
# q_fertiirrigacao                  0.00
# data1m                            0.00
# data3m                            0.00
# data6m                            0.00
# data12m                           0.00
# q_ifp                             0.00
# q_ilpf                            0.00
# q_ilp                             0.00
# motivo_desclassificacao           0.00
# med7d_formituinst                 0.00
# peso                              0.00
# acabamento                        0.00
# maturidade                        0.00
# tipificacao                       0.00
# identificador_lote                0.00
# estabelecimento_identificador     0.00
# data_abate                        0.00
# data7d                            0.00
# med7d_formitumax                  0.00
# med6m_umidinst                    0.00
# med3m_formitumax                  0.00
# med6m_tempmin                     0.00
# med6m_tempmax                     0.00
# med6m_tempinst                    0.00
# tot6m_chuva                       0.00
# med3m_prer_boi                    0.00
# med3m_prer_milho                  0.00
# med3m_prer_soja                   0.00
# med3m_formituinst                 0.00
# med7d_prer_soja                   0.00
# med1m_prer_boi                    0.00
# estabelecimento_municipio         0.00
# med1m_prer_soja                   0.00
# med1m_formitumax                  0.00
# med1m_formituinst                 0.00
# med7d_prer_boi                    0.00
# med7d_prer_milho                  0.00
# classificacao                     0.00
# dtype: float64

# %%
#missing_count = df.isnull().sum()
#value_count = df.isnull().count()
#missing_percentage = round(missing_count / value_count * 100,2)

# %%
#missing_df = pd.DataFrame({'count': missing_count, 'percentage':missing_percentage})

# %%
#print(missing_df)

# %%
#barchart = missing_df.plot.bar(y='percentage')
#for index, percentage in enumerate(missing_percentage): barchart.text(index, percentage, str(percentage)+'%')

# %% [markdown]
# ## Descrição dos dados

# %%
#df.describe(include='all').T
df.describe().T
# Out:
#                                    count           mean            std  \
# id_animal                      1061451.0  530726.000000  306414.654627
# estabelecimento_identificador  1061451.0    3913.340606    2063.337035
# identificador_lote             1061451.0   46933.560856   22441.555052
# peso                           1061451.0     268.062509      46.513845
# q_classificacao_estabel        1012155.0      24.513777       3.620091
# tot7d_chuva                     935785.0    6984.879556   12369.306301
# med7d_tempinst                 1016177.0      24.107506       2.899904
# med7d_tempmax                  1015010.0      30.837630       2.944770
# med7d_tempmin                  1015010.0      18.915321       3.465536
# med7d_umidinst                 1017166.0      67.407977      11.895551
# med7d_umidmax                  1017322.0      87.127849       9.741808
# med7d_umidmin                  1016228.0      42.515421      12.669623
# med7d_velventomax              1018233.0      14.799115       4.586035
# med7d_formituinst              1061451.0      70.306240       6.954855
# med7d_formitumax               1061451.0      82.723847       9.942608
# med7d_num_pixels               1017247.0   26825.642334   29575.930640
# med7d_ndvi                     1017247.0       0.545676       0.100539
# med7d_evi                      1017247.0       0.346935       0.086788
# med7d_prer_soja                1061451.0      81.171517       8.374413
# med7d_prer_milho               1061451.0      35.603838       4.815065
# med7d_prer_boi                 1061451.0     143.260352       5.570557
# tot1m_chuva                    1010188.0   22434.864365   31119.757976
# med1m_tempinst                 1033465.0      23.927243       2.611175
# med1m_tempmax                  1033296.0      30.714694       2.507344
# med1m_tempmin                  1033296.0      18.678890       3.211675
# med1m_umidinst                 1039259.0      67.174312      10.148309
# med1m_umidmax                  1039090.0      87.046601       8.539983
# med1m_umidmin                  1039090.0      42.160692      10.475772
# med1m_velventomax              1039259.0      14.844265       4.168938
# med1m_formituinst              1061451.0      69.980611       6.417196
# med1m_formitumax               1061451.0      82.432177       9.146227
# med1m_num_pixels               1017247.0   26825.642334   29575.930640
# med1m_ndvi                     1017247.0       0.541885       0.098446
# med1m_evi                      1017247.0       0.342435       0.084089
# med1m_prer_soja                1061451.0      81.135009       8.499948
# med1m_prer_milho               1061451.0      35.539765       4.876560
# med1m_prer_boi                 1061451.0     142.887313       5.520113
# tot3m_chuva                    1044107.0   55481.515050   66558.460760
# med3m_tempinst                 1056202.0      23.589671       2.204532
# med3m_tempmax                  1056202.0      30.561414       2.233700
# med3m_tempmin                  1056202.0      18.192112       2.684616
# med3m_umidinst                 1061271.0      66.621044       8.306025
# med3m_umidmax                  1061271.0      86.879643       7.396039
# med3m_umidmin                  1061271.0      41.112056       8.075668
# med3m_velventomax              1061271.0      14.748823       3.824006
# med3m_formituinst              1061451.0      69.347450       5.479971
# med3m_formitumax               1061451.0      81.942987       7.952395
# med3m_num_pixels               1017247.0   26825.642334   29575.930640
# med3m_ndvi                     1017247.0       0.533443       0.086641
# med3m_evi                      1017247.0       0.332190       0.071566
# med3m_prer_soja                1061451.0      80.610403       8.492598
# med3m_prer_milho               1061451.0      35.382515       4.954285
# med3m_prer_boi                 1061451.0     142.070400       5.100192
# tot6m_chuva                    1061451.0   97279.710748   93186.411030
# med6m_tempinst                 1061451.0      23.465407       1.647932
# med6m_tempmax                  1061451.0      30.416819       1.823493
# med6m_tempmin                  1061451.0      18.160398       2.008094
# med6m_umidinst                 1061451.0      67.684697       6.251726
# med6m_umidmax                  1061451.0      87.580475       6.455439
# med6m_umidmin                  1061451.0      41.810105       5.913237
# med6m_velventomax              1061451.0      14.423409       3.533727
# med6m_formituinst              1061451.0      69.379060       4.251209
# med6m_formitumax               1061451.0      81.954692       6.328095
# med6m_num_pixels               1017247.0   26825.642334   29575.930640
# med6m_ndvi                     1017247.0       0.546540       0.063231
# med6m_evi                      1017247.0       0.339919       0.052857
# med6m_prer_soja                1061451.0      78.931210       7.703585
# med6m_prer_milho               1061451.0      34.968370       4.830673
# med6m_prer_boi                 1061451.0     141.088872       3.969229
# tot12m_chuva                   1061451.0  224271.611081  192381.503751
# med12m_tempinst                1061451.0      23.938787       1.071517
# med12m_tempmax                 1061451.0      30.723980       1.355985
# med12m_tempmin                 1061451.0      18.857639       1.207060
# med12m_umidinst                1061451.0      69.243894       4.348585
# med12m_umidmax                 1061451.0      88.436535       5.671658
# med12m_umidmin                 1061451.0      43.369118       4.250665
# med12m_velventomax             1061451.0      14.559612       3.208327
# med12m_formituinst             1061451.0      70.115373       3.228322
# med12m_formitumax              1061451.0      82.422638       4.825786
# med12m_num_pixels              1017247.0   26825.642334   29575.930640
# med12m_ndvi                    1017247.0       0.569540       0.037575
# med12m_evi                     1017247.0       0.360457       0.031601
# med12m_prer_soja               1061451.0      75.930744       5.104972
# med12m_prer_milho              1061451.0      33.610558       3.164784
# med12m_prer_boi                1061451.0     140.843757       2.636037
# cnt7d_cl_itumax                1014881.0       0.859881       0.202862
# cnt7d_cl_ituinst               1014932.0       0.073377       0.184951
# cnt1m_cl_itumax                1033296.0       0.851301       0.169276
# cnt1m_cl_ituinst               1033465.0       0.065001       0.138242
# cnt3m_cl_itumax                1056202.0       0.833125       0.141789
# cnt3m_cl_ituinst               1056202.0       0.055296       0.105888
# cnt6m_cl_itumax                1061451.0       0.833656       0.116307
# cnt6m_cl_ituinst               1061451.0       0.053258       0.081674
# cnt12m_cl_itumax               1061451.0       0.863617       0.079437
# cnt12m_cl_ituinst              1061451.0       0.060628       0.068653
# ano                            1061451.0    2017.683572       0.465082
# classificacao                  1061451.0       0.836301       0.370002
#
#                                      min          25%          50%  \
# id_animal                         1.0000  265363.5000  530726.0000
# estabelecimento_identificador     1.0000    1712.0000    4403.0000
# identificador_lote                2.0000   25040.0000   49413.0000
# peso                            102.0000     236.5000     271.6000
# q_classificacao_estabel          21.0000      21.0000      26.0000
# tot7d_chuva                       0.0000      15.6000    1998.0000
# med7d_tempinst                   11.7500      22.3500      24.5600
# med7d_tempmax                    14.7000      29.1800      30.9300
# med7d_tempmin                     4.9000      16.4100      19.7400
# med7d_umidinst                   12.2500      60.5300      69.8400
# med7d_umidmax                     7.0000      83.4400      89.6700
# med7d_umidmin                    10.0000      33.2200      43.8900
# med7d_velventomax                 0.0000      11.6400      14.6400
# med7d_formituinst                33.4000      67.6600      72.2700
# med7d_formitumax                 31.8000      81.0500      84.9100
# med7d_num_pixels                151.0000    6365.0000   13526.0000
# med7d_ndvi                        0.2900       0.4600       0.5700
# med7d_evi                         0.1600       0.2700       0.3700
# med7d_prer_soja                  64.5200      72.7700      82.6900
# med7d_prer_milho                 25.3900      31.9500      36.7000
# med7d_prer_boi                  123.9800     140.3100     144.3200
# tot1m_chuva                       0.0000    1327.2000   10611.6000
# med1m_tempinst                   14.8700      21.9400      24.5200
# med1m_tempmax                    18.6700      29.3600      30.8800
# med1m_tempmin                     9.5900      15.8300      19.5200
# med1m_umidinst                   12.2500      61.2100      69.0000
# med1m_umidmax                    10.0000      83.3400      88.7500
# med1m_umidmin                    10.0000      34.5600      43.0000
# med1m_velventomax                 0.0000      11.6800      14.7300
# med1m_formituinst                40.5100      67.0800      71.7900
# med1m_formitumax                 38.4700      80.3500      84.6400
# med1m_num_pixels                151.0000    6365.0000   13526.0000
# med1m_ndvi                        0.3000       0.4600       0.5700
# med1m_evi                         0.1600       0.2700       0.3500
# med1m_prer_soja                  65.8400      72.3900      82.8500
# med1m_prer_milho                 25.9600      31.7500      36.7300
# med1m_prer_boi                  124.6000     140.3500     143.7900
# tot3m_chuva                       0.0000   10395.0000   30874.0000
# med3m_tempinst                   16.8600      21.9200      23.8500
# med3m_tempmax                    23.1800      29.1100      30.6900
# med3m_tempmin                    10.9600      15.9200      18.3800
# med3m_umidinst                   21.9100      60.8600      67.5100
# med3m_umidmax                    21.1900      83.1200      87.7600
# med3m_umidmin                    12.7300      35.1100      41.7100
# med3m_velventomax                 1.0100      11.7900      14.4100
# med3m_formituinst                44.3300      67.1000      70.0600
# med3m_formitumax                 44.0000      79.7600      83.7800
# med3m_num_pixels                151.0000    6365.0000   13526.0000
# med3m_ndvi                        0.3200       0.4600       0.5400
# med3m_evi                         0.1700       0.2700       0.3300
# med3m_prer_soja                  67.8700      71.7300      82.4900
# med3m_prer_milho                 26.5700      30.8600      37.5600
# med3m_prer_boi                  128.3200     140.4000     142.4500
# tot6m_chuva                       0.0000   29360.0000   69583.5000
# med6m_tempinst                   18.4400      22.4400      23.3900
# med6m_tempmax                    24.9800      29.0300      30.4000
# med6m_tempmin                    13.1700      16.7200      17.9200
# med6m_umidinst                   21.9100      63.1900      68.1200
# med6m_umidmax                    21.1900      83.9300      88.3800
# med6m_umidmin                    12.7300      37.3100      41.9300
# med6m_velventomax                 3.4500      11.5800      14.1000
# med6m_formituinst                52.6500      67.9000      69.9800
# med6m_formitumax                 57.9500      80.0200      82.7200
# med6m_num_pixels                151.0000    6365.0000   13526.0000
# med6m_ndvi                        0.3900       0.5000       0.5500
# med6m_evi                         0.2100       0.3000       0.3400
# med6m_prer_soja                  69.2200      71.2400      77.9600
# med6m_prer_milho                 27.4700      29.6800      36.5400
# med6m_prer_boi                  133.7300     137.1000     142.7500
# tot12m_chuva                     19.2000   88142.6000  172010.0000
# med12m_tempinst                  21.0900      23.1100      23.9400
# med12m_tempmax                   27.2400      29.7400      30.4000
# med12m_tempmin                   15.9400      17.9500      18.9900
# med12m_umidinst                  21.9100      66.6600      69.2600
# med12m_umidmax                   21.1900      86.0400      88.5800
# med12m_umidmin                   12.7300      40.9600      43.7500
# med12m_velventomax                7.3100      11.9400      13.8300
# med12m_formituinst               57.7700      68.7200      70.9000
# med12m_formitumax                62.0900      80.1900      82.8700
# med12m_num_pixels               151.0000    6365.0000   13526.0000
# med12m_ndvi                       0.4900       0.5400       0.5700
# med12m_evi                        0.3000       0.3400       0.3600
# med12m_prer_soja                 70.6600      70.9900      74.3900
# med12m_prer_milho                30.0100      30.3400      33.3000
# med12m_prer_boi                 136.8500     138.6100     140.0400
# cnt7d_cl_itumax                   0.0000       0.7778       1.0000
# cnt7d_cl_ituinst                  0.0000       0.0000       0.0000
# cnt1m_cl_itumax                   0.0000       0.7813       0.9063
# cnt1m_cl_ituinst                  0.0000       0.0000       0.0000
# cnt3m_cl_itumax                   0.0000       0.7447       0.8723
# cnt3m_cl_ituinst                  0.0000       0.0000       0.0000
# cnt6m_cl_itumax                   0.0909       0.7663       0.8587
# cnt6m_cl_ituinst                  0.0000       0.0000       0.0217
# cnt12m_cl_itumax                  0.0952       0.8237       0.8702
# cnt12m_cl_ituinst                 0.0000       0.0072       0.0463
# ano                            2017.0000    2017.0000    2018.0000
# classificacao                     0.0000       1.0000       1.0000
#
#                                        75%           max
# id_animal                      796088.5000  1.061451e+06
# estabelecimento_identificador    5349.0000  8.255000e+03
# identificador_lote              68622.0000  8.084800e+04
# peso                              299.0000  1.566000e+03
# q_classificacao_estabel            26.0000  3.000000e+01
# tot7d_chuva                      8448.8000  1.266720e+05
# med7d_tempinst                     26.0500  3.524000e+01
# med7d_tempmax                      32.7600  4.005000e+01
# med7d_tempmin                      21.3900  3.277000e+01
# med7d_umidinst                     76.2600  9.671000e+01
# med7d_umidmax                      93.6700  1.000000e+02
# med7d_umidmin                      51.2200  8.288000e+01
# med7d_velventomax                  18.1600  2.728000e+01
# med7d_formituinst                  74.6400  8.204000e+01
# med7d_formitumax                   88.1400  9.850000e+01
# med7d_num_pixels                32960.0000  1.065410e+05
# med7d_ndvi                          0.6200  7.400000e-01
# med7d_evi                           0.4100  5.700000e-01
# med7d_prer_soja                    88.0200  9.642000e+01
# med7d_prer_milho                   39.6200  4.505000e+01
# med7d_prer_boi                    146.7600  1.522700e+02
# tot1m_chuva                     31095.4000  2.729484e+05
# med1m_tempinst                     25.8100  3.297000e+01
# med1m_tempmax                      32.3700  3.970000e+01
# med1m_tempmin                      21.1100  3.035000e+01
# med1m_umidinst                     74.6200  9.671000e+01
# med1m_umidmax                      92.8800  1.000000e+02
# med1m_umidmin                      49.9100  7.877000e+01
# med1m_velventomax                  17.9300  2.504000e+01
# med1m_formituinst                  74.2800  8.118000e+01
# med1m_formitumax                   87.5900  9.593000e+01
# med1m_num_pixels                32960.0000  1.065410e+05
# med1m_ndvi                          0.6200  7.300000e-01
# med1m_evi                           0.4100  5.200000e-01
# med1m_prer_soja                    88.2900  9.564000e+01
# med1m_prer_milho                   39.9600  4.365000e+01
# med1m_prer_boi                    146.5300  1.502600e+02
# tot3m_chuva                     75656.0000  5.969460e+05
# med3m_tempinst                     25.3000  3.070000e+01
# med3m_tempmax                      32.0900  4.005000e+01
# med3m_tempmin                      20.4500  2.640000e+01
# med3m_umidinst                     73.0800  8.468000e+01
# med3m_umidmax                      92.4100  9.904000e+01
# med3m_umidmin                      47.3100  6.715000e+01
# med3m_velventomax                  17.7900  2.424000e+01
# med3m_formituinst                  73.0700  7.895000e+01
# med3m_formitumax                   86.9000  9.266000e+01
# med3m_num_pixels                32960.0000  1.065410e+05
# med3m_ndvi                          0.6100  7.200000e-01
# med3m_evi                           0.3900  5.100000e-01
# med3m_prer_soja                    88.4600  9.188000e+01
# med3m_prer_milho                   39.6100  4.167000e+01
# med3m_prer_boi                    145.7600  1.484600e+02
# tot6m_chuva                    138714.8000  7.458164e+05
# med6m_tempinst                     24.5400  2.835000e+01
# med6m_tempmax                      31.7800  3.569000e+01
# med6m_tempmin                      19.6500  2.452000e+01
# med6m_umidinst                     71.9500  8.093000e+01
# med6m_umidmax                      92.3100  9.904000e+01
# med6m_umidmin                      46.1000  6.308000e+01
# med6m_velventomax                  17.1100  2.257000e+01
# med6m_formituinst                  71.9700  7.835000e+01
# med6m_formitumax                   86.6700  9.170000e+01
# med6m_num_pixels                32960.0000  1.065410e+05
# med6m_ndvi                          0.6000  7.100000e-01
# med6m_evi                           0.3800  4.900000e-01
# med6m_prer_soja                    88.2100  8.915000e+01
# med6m_prer_milho                   39.4300  4.049000e+01
# med6m_prer_boi                    143.9700  1.476100e+02
# tot12m_chuva                   307474.2000  1.535736e+06
# med12m_tempinst                    24.6400  2.803000e+01
# med12m_tempmax                     32.0200  3.456000e+01
# med12m_tempmin                     19.6400  2.413000e+01
# med12m_umidinst                    72.0800  8.093000e+01
# med12m_umidmax                     92.8800  9.904000e+01
# med12m_umidmin                     45.8200  6.082000e+01
# med12m_velventomax                 16.7700  2.156000e+01
# med12m_formituinst                 72.2500  7.743000e+01
# med12m_formitumax                  85.3400  9.170000e+01
# med12m_num_pixels               32960.0000  1.065410e+05
# med12m_ndvi                         0.6000  7.000000e-01
# med12m_evi                          0.3800  4.700000e-01
# med12m_prer_soja                   81.2900  8.443000e+01
# med12m_prer_milho                  37.1600  3.849000e+01
# med12m_prer_boi                   143.5500  1.476100e+02
# cnt7d_cl_itumax                     1.0000  1.000000e+00
# cnt7d_cl_ituinst                    0.0000  1.000000e+00
# cnt1m_cl_itumax                     0.9688  1.000000e+00
# cnt1m_cl_ituinst                    0.0625  1.000000e+00
# cnt3m_cl_itumax                     0.9468  1.000000e+00
# cnt3m_cl_ituinst                    0.0638  1.000000e+00
# cnt6m_cl_itumax                     0.9231  1.000000e+00
# cnt6m_cl_ituinst                    0.0725  6.196000e-01
# cnt12m_cl_itumax                    0.9273  1.000000e+00
# cnt12m_cl_ituinst                   0.0851  5.182000e-01
# ano                              2018.0000  2.018000e+03
# classificacao                       1.0000  1.000000e+00

# %% [markdown]
# ## Gráficos dados numéricos

# %%
atributos_categoricos = list(df.select_dtypes(include=['object']).columns)
atributos_numericos = list(df.select_dtypes(include=['float64', 'int64']).columns)

print('Atributos Categoricos:', atributos_categoricos)
# Out:
# Atributos Categoricos: ['estabelecimento_municipio', 'data_abate', 'tipificacao', 'maturidade', 'acabamento', 'motivo_desclassificacao', 'q_outros_incentiv', 'q_pratica_recuperacao_pa', 'q_fertiirrigacao', 'q_ilp', 'q_ilpf', 'q_ifp', 'q_fabrica_racao', 'q_identificacao_individual', 'q_regua_manejo', 'q_bpa', 'q_aliancas_mercadolog', 'q_qual_alianca', 'q_cobertura_vegetal_80_area', 'q_erosaoo_sulco_20_area', 'q_sisbov', 'q_lista_trace', 'data12m', 'data6m', 'data3m', 'data1m', 'data7d', 'categoria']

# %%
print('Atributos Numericos:', atributos_numericos)
# Out:
# Atributos Numericos: ['id_animal', 'estabelecimento_identificador', 'identificador_lote', 'peso', 'q_classificacao_estabel', 'tot7d_chuva', 'med7d_tempinst', 'med7d_tempmax', 'med7d_tempmin', 'med7d_umidinst', 'med7d_umidmax', 'med7d_umidmin', 'med7d_velventomax', 'med7d_formituinst', 'med7d_formitumax', 'med7d_num_pixels', 'med7d_ndvi', 'med7d_evi', 'med7d_prer_soja', 'med7d_prer_milho', 'med7d_prer_boi', 'tot1m_chuva', 'med1m_tempinst', 'med1m_tempmax', 'med1m_tempmin', 'med1m_umidinst', 'med1m_umidmax', 'med1m_umidmin', 'med1m_velventomax', 'med1m_formituinst', 'med1m_formitumax', 'med1m_num_pixels', 'med1m_ndvi', 'med1m_evi', 'med1m_prer_soja', 'med1m_prer_milho', 'med1m_prer_boi', 'tot3m_chuva', 'med3m_tempinst', 'med3m_tempmax', 'med3m_tempmin', 'med3m_umidinst', 'med3m_umidmax', 'med3m_umidmin', 'med3m_velventomax', 'med3m_formituinst', 'med3m_formitumax', 'med3m_num_pixels', 'med3m_ndvi', 'med3m_evi', 'med3m_prer_soja', 'med3m_prer_milho', 'med3m_prer_boi', 'tot6m_chuva', 'med6m_tempinst', 'med6m_tempmax', 'med6m_tempmin', 'med6m_umidinst', 'med6m_umidmax', 'med6m_umidmin', 'med6m_velventomax', 'med6m_formituinst', 'med6m_formitumax', 'med6m_num_pixels', 'med6m_ndvi', 'med6m_evi', 'med6m_prer_soja', 'med6m_prer_milho', 'med6m_prer_boi', 'tot12m_chuva', 'med12m_tempinst', 'med12m_tempmax', 'med12m_tempmin', 'med12m_umidinst', 'med12m_umidmax', 'med12m_umidmin', 'med12m_velventomax', 'med12m_formituinst', 'med12m_formitumax', 'med12m_num_pixels', 'med12m_ndvi', 'med12m_evi', 'med12m_prer_soja', 'med12m_prer_milho', 'med12m_prer_boi', 'cnt7d_cl_itumax', 'cnt7d_cl_ituinst', 'cnt1m_cl_itumax', 'cnt1m_cl_ituinst', 'cnt3m_cl_itumax', 'cnt3m_cl_ituinst', 'cnt6m_cl_itumax', 'cnt6m_cl_ituinst', 'cnt12m_cl_itumax', 'cnt12m_cl_ituinst', 'ano', 'classificacao']

# %%
selecao = ['peso', 'q_classificacao_estabel', 'tot7d_chuva', 'med7d_tempinst', 'med7d_tempmax', 'med7d_tempmin', 'med7d_umidinst', 'med7d_umidmax', 'med7d_umidmin', 'med7d_velventomax', 'med7d_formituinst', 'med7d_formitumax', 'med7d_num_pixels', 'med7d_ndvi', 'med7d_evi', 'med7d_prer_soja', 'med7d_prer_milho', 'med7d_prer_boi']

# %%
dados_numericos = df[selecao]

# %%
dados_numericos.head(10)
# Out:
#     peso  q_classificacao_estabel  tot7d_chuva  med7d_tempinst  med7d_tempmax  \
# 0  283.0                     30.0         96.0           23.73          30.02
# 1  268.8                     30.0         96.0           23.73          30.02
# 2  282.4                     30.0         96.0           23.73          30.02
# 3  271.4                     30.0         96.0           23.73          30.02
#    med12m_prer_milho  med12m_prer_boi  cnt7d_cl_itumax  cnt7d_cl_ituinst  \
# 0               36.0           147.61              1.0               0.0
# 1               36.0           147.61              1.0               0.0
# 2               36.0           147.61              1.0               0.0
# 3               36.0           147.61              1.0               0.0
# 4               36.0           147.61              1.0               0.0
# 5               36.0           147.61              1.0               0.0
# 6               36.0           147.61              1.0               0.0
# 7               36.0           147.61              1.0               0.0
# 8               36.0           147.61              1.0               0.0
# 9               36.0           147.61              1.0               0.0
#
#    cnt1m_cl_itumax  cnt1m_cl_ituinst  cnt3m_cl_itumax  cnt3m_cl_ituinst  \
# 0           0.8889               0.0           0.8276               0.0
# 1           0.8889               0.0           0.8276               0.0
# 2           0.8889               0.0           0.8276               0.0
# 3           0.8889               0.0           0.8276               0.0
# 4           0.8889               0.0           0.8276               0.0
# 5           0.8889               0.0           0.8276               0.0
# 6           0.8889               0.0           0.8276               0.0
# 7           0.8889               0.0           0.8276               0.0
# 8           0.8889               0.0           0.8276               0.0
# 9           0.8889               0.0           0.8276               0.0
#
#    cnt6m_cl_itumax  cnt6m_cl_ituinst  cnt12m_cl_itumax  cnt12m_cl_ituinst  \
# 0           0.8276               0.0            0.8276                0.0
# 1           0.8276               0.0            0.8276                0.0
# 2           0.8276               0.0            0.8276                0.0
# 3           0.8276               0.0            0.8276                0.0
# 4           0.8276               0.0            0.8276                0.0
# 5           0.8276               0.0            0.8276                0.0
# 6           0.8276               0.0            0.8276                0.0
# 7           0.8276               0.0            0.8276                0.0
# 8           0.8276               0.0            0.8276                0.0
# 9           0.8276               0.0            0.8276                0.0
#
#     ano  classificacao
# 0  2017              0
# 1  2017              1
# 2  2017              1
# 3  2017              0
# 4  2017              1
# 5  2017              1
# 6  2017              1
# 7  2017              1
# 8  2017              1
# 9  2017              1

# %%
df.hist(column=selecaoum, figsize=(20,20), xrot=45,xlabelsize=10, ylabelsize=10)
plt.show()

# %% [markdown]
# ### Peso

# %%
df.peso.hist(figsize=(5,5), xrot=45, bins=50)
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["peso"])
plt.title("Peso", size=18)
# Out:
# Text(0.5, 1.0, 'Peso')

# %% [markdown]
# ### Classificação do Estabelecimento

# %%
df.q_classificacao_estabel.hist(figsize=(5,5), xrot=45, bins=20)
plt.show()

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["q_classificacao_estabel"])
plt.title("Classificação do Estabelecimento", size=18)
# Out:
# Text(0.5, 1.0, 'Classificação do Estabelecimento')

# %% [markdown]
# ## Gráficos de dados categóricos

# %% [markdown]
# ### Tipificação

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="tipificacao", data=df)

# %% [markdown]
# ### Maturidade

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="maturidade", data=df)

# %% [markdown]
# ### Acabamento

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="acabamento", data=df)

# %% [markdown]
# ### Motivo de desclassificacao

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="motivo_desclassificacao", data=df)

# %% [markdown]
# ### Categorias

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="categoria", data=df)
