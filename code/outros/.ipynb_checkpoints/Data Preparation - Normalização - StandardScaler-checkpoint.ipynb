# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../../dados/dadosTransformados_v1.csv', sep=';')

# %%
dados_alvo = df['peso']

# %%
dados_alvo = pd.DataFrame(data=dados_alvo, columns=['peso'])

# %%
dados_preditores = df.drop('peso', axis=1)

# %%
dados_preditores_labels = dados_preditores.columns.values.tolist()

# %%
dados_preditores[dados_preditores_labels] = MinMaxScaler().fit_transform(dados_preditores[dados_preditores_labels].values)

# %%
dados_preditores.sample(5)
# Out:
#         tipificacao_1  tipificacao_2  tipificacao_3  maturidade  acabamento  \
# 483825            0.0            1.0            0.0    0.714286        0.50
# 874074            1.0            0.0            0.0    0.000000        0.25
# 877194            1.0            0.0            0.0    0.000000        0.50
# 48062             1.0            0.0            0.0    0.000000        0.50
# 668620            0.0            1.0            0.0    0.142857        0.50
#
#         classificacao_estabelecimento  outros_incentivos  \
# 483825                       0.000000                0.0
# 874074                       0.555556                0.0
# 877194                       0.555556                0.0
# 48062                        0.555556                0.0
# 668620                       0.000000                0.0
#
#         pratica_recuperacao_pastagem  fertiirrigacao  ilp  ...  \
# 483825                           1.0             0.0  1.0  ...
# 874074                           0.0             0.0  0.0  ...
# 877194                           1.0             0.0  1.0  ...
# 48062                            1.0             1.0  0.0  ...
# 668620                           0.0             0.0  0.0  ...
#
#         cnt1m_cl_ituinst  cnt3m_cl_ituinst  cnt6m_cl_ituinst  \
# 483825          1.000000          0.967578          0.783296
# 874074          0.206948          0.393732          0.558393
# 877194          0.572421          0.674691          0.794424
# 48062           0.893105          0.858599          0.805669
# 668620          0.724105          0.743440          0.660771
#
#         cnt12m_cl_ituinst  ano  categoria  classificacao  longitude  latitude  \
# 483825           0.793018  1.0        1.0            0.0   0.490349  0.050235
# 874074           0.345964  1.0        0.2            1.0   0.909825  0.499025
# 877194           0.706592  1.0        0.0            1.0   0.403245  0.223820
# 48062            0.829224  0.0        0.0            1.0   0.566229  0.694805
# 668620           0.488191  1.0        0.2            1.0   0.461441  1.000000
#
#              mes
# 483825  0.454545
# 874074  0.909091
# 877194  0.909091
# 48062   0.545455
# 668620  0.727273
#
# [5 rows x 52 columns]

# %%
dados_preditores = pd.DataFrame(dados_preditores)

# %%
dados_preditores.sample(5)
# Out:
#         tipificacao_1  tipificacao_2  tipificacao_3  maturidade  acabamento  \
# 274763            1.0            0.0            0.0    0.000000        0.25
# 448128            1.0            0.0            0.0    0.428571        0.25
# 931471            0.0            0.0            1.0    0.142857        0.50
# 596630            0.0            0.0            1.0    0.000000        0.25
# 510810            1.0            0.0            0.0    0.000000        0.50
#
#         classificacao_estabelecimento  outros_incentivos  \
# 274763                       1.000000                1.0
# 448128                       0.000000                0.0
# 931471                       1.000000                0.0
# 596630                       0.555556                0.0
# 510810                       0.555556                0.0
#
#         pratica_recuperacao_pastagem  fertiirrigacao  ilp  ...  \
# 274763                           1.0             0.0  1.0  ...
# 448128                           0.0             0.0  0.0  ...
# 931471                           0.0             0.0  0.0  ...
# 596630                           0.0             0.0  0.0  ...
# 510810                           1.0             1.0  0.0  ...
#
#         cnt1m_cl_ituinst  cnt3m_cl_ituinst  cnt6m_cl_ituinst  \
# 274763          0.189097          0.245608          0.322479
# 448128          0.965473          0.743440          0.673539
# 931471          0.287333          0.292778          0.472180
# 596630          0.793159          0.731837          0.481551
# 510810          0.852592          0.651052          0.536371
#
#         cnt12m_cl_ituinst  ano  categoria  classificacao  longitude  latitude  \
# 274763           0.274591  0.0        0.2            1.0   0.861776  0.427417
# 448128           0.764729  1.0        1.0            0.0   0.389444  0.137911
# 931471           0.352582  1.0        0.2            1.0   0.178904  0.535550
# 596630           0.290164  1.0        1.0            0.0   0.909825  0.499025
# 510810           0.616403  1.0        0.0            1.0   0.607701  0.552912
#
#              mes
# 274763  1.000000
# 448128  0.363636
# 931471  1.000000
# 596630  0.636364
# 510810  0.454545
#
# [5 rows x 52 columns]

# %%
df = dados_preditores.join(dados_alvo)

# %%
df.to_csv("dados_normalizados.csv",sep=';', index = False)
