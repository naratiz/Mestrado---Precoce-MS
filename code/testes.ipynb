# %% [markdown]
# ## Converter dados para float

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/dadosCompletos.csv', sep=';')

# %%
#lendo algumas colunas selecionadas em colunas colunas =['cc1, 'cc2']
#df_coluns = pd.read_csv('./dados/dadosCompletos.csv', encoding='utf-8', sep=';', usecols=colunas )

# %%
pd.set_option('display.max_columns',999)
pd.set_option("display.max_rows", 999)

# %%
#df.info(verbose=True)

# %%
#df.columns.values

# %%
df.head(5)
# Out:
#    id_animal estabelecimento_municipio data_abate  \
# 0          1         PARAISO DAS AGUAS  09FEB2017
# 1          2         PARAISO DAS AGUAS  09FEB2017
# 2          3         PARAISO DAS AGUAS  09FEB2017
# 3          4         PARAISO DAS AGUAS  09FEB2017
# 4          5         PARAISO DAS AGUAS  09FEB2017
#
#    estabelecimento_identificador  identificador_lote     tipificacao  \
# 0                           1034                   2   macho inteiro
# 1                           1034                   2  macho castrado
# 2                           1034                   2  macho castrado
# 3                           1034                   2  macho castrado
# 4                           1034                   2  macho castrado
#
#       maturidade                                         acabamento   peso  \
# 0    Dois dentes                            magra - gordura ausente  283.0
# 1  Quatro dentes  gordura mediana - acima de 3 a ata 6 mm de esp...  268.8
# ...

# %%
print('A base de dados apresenta {} registros e {} variáveis'.format(df.shape[0], df.shape[1]))
# Out:
# A base de dados apresenta 1061451 registros e 125 variáveis

# %%
#df.acabamento.value_counts()

# %%
#df.query('estabelecimento_identificador == 5209')

# %%
#transformar para tipo data
df['data_abate'] = df['data_abate'].astype('datetime64')

# %%
df.data_abate.describe()
# Out:
# <ipython-input-14-5176408b6beb>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.data_abate.describe()
# count                 1061451
# unique                    504
# top       2018-11-21 00:00:00
# freq                     6155
# first     2017-02-09 00:00:00
# last      2018-12-31 00:00:00
# Name: data_abate, dtype: object
