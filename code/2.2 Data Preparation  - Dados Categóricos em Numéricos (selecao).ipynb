# %% [markdown]
# # Transformação - Dados Categóricos em Numéricos

# %%
#!pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.2.2-py2.py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0.0 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=0.21.1 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: patsy>=0.5.1 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: numpy>=1.14.0 in /home/inara/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/inara/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/inara/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in /home/inara/anaconda3/lib/python3.8/site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /home/inara/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/inara/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %%
import pandas as pd
import numpy as np
import datetime
import category_encoders as ce
from category_encoders.one_hot import OneHotEncoder

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('../../dados/dados_limpeza.csv', sep=';')

# %%
pd.set_option('display.max_columns',999)
pd.set_option("display.max_rows", 999)

# %%
df.tail(20)
# Out:
#        estabelecimento_municipio  data_abate     tipificacao     maturidade  \
# 960919                   TERENOS  2018-12-31  macho castrado  Quatro dentes
# 960920                   TERENOS  2018-12-31  macho castrado  Quatro dentes
# 960921                   TERENOS  2018-12-31  macho castrado  Quatro dentes
# 960922                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960923                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960924                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960925                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960926                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960927                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960928                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960929                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960930                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960931                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960932                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960933                   TERENOS  2018-12-31  macho castrado    Oito dentes
# 960934                   TERENOS  2018-12-31  macho castrado    Oito dentes
# 960935                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960936                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960937                   TERENOS  2018-12-31  macho castrado    Seis dentes
# 960938                   TERENOS  2018-12-31  macho castrado    Seis dentes
#
#                                                acabamento   peso  \
# 960919  gordura mediana - acima de 3 a ata 6 mm de esp...  316.0
# 960920  gordura mediana - acima de 3 a ata 6 mm de esp...  317.6
# 960921  gordura mediana - acima de 3 a ata 6 mm de esp...  296.6
# 960922  gordura mediana - acima de 3 a ata 6 mm de esp...  321.2
# 960923  gordura uniforme - acima de 6 e ata 10 mm de e...  295.0
# 960924  gordura mediana - acima de 3 a ata 6 mm de esp...  288.2
# 960925  gordura mediana - acima de 3 a ata 6 mm de esp...  308.6
# 960926  gordura mediana - acima de 3 a ata 6 mm de esp...  303.8
# 960927  gordura mediana - acima de 3 a ata 6 mm de esp...  316.0
# 960928  gordura uniforme - acima de 6 e ata 10 mm de e...  305.2
# 960929  gordura mediana - acima de 3 a ata 6 mm de esp...  297.0
# 960930  gordura mediana - acima de 3 a ata 6 mm de esp...  285.6
# 960931  gordura mediana - acima de 3 a ata 6 mm de esp...  271.2
# 960932  gordura mediana - acima de 3 a ata 6 mm de esp...  322.0
# 960933  gordura uniforme - acima de 6 e ata 10 mm de e...  331.8
# 960934  gordura mediana - acima de 3 a ata 6 mm de esp...  317.4
# 960935  gordura uniforme - acima de 6 e ata 10 mm de e...  318.2
# 960936  gordura uniforme - acima de 6 e ata 10 mm de e...  284.6
# 960937  gordura mediana - acima de 3 a ata 6 mm de esp...  295.6
# 960938  gordura mediana - acima de 3 a ata 6 mm de esp...  272.4
#
#         classificacao_estabelecimento outros_incentivos  \
# 960919                           30.0               NÃO
# 960920                           30.0               NÃO
# 960921                           30.0               NÃO
# 960922                           30.0               NÃO
# 960923                           30.0               NÃO
# 960924                           30.0               NÃO
# 960925                           30.0               NÃO
# 960926                           30.0               NÃO
# 960927                           30.0               NÃO
# 960928                           30.0               NÃO
# 960929                           30.0               NÃO
# 960930                           30.0               NÃO
# 960931                           30.0               NÃO
# 960932                           30.0               NÃO
# 960933                           30.0               NÃO
# 960934                           30.0               NÃO
# 960935                           30.0               NÃO
# 960936                           30.0               NÃO
# 960937                           30.0               NÃO
# 960938                           30.0               NÃO
#
#        pratica_recuperacao_pastagem fertiirrigacao  ilp ilpf  ifp  \
# 960919                          SIM            NÃO  NÃO  SIM  NÃO
# 960920                          SIM            NÃO  NÃO  SIM  NÃO
# 960921                          SIM            NÃO  NÃO  SIM  NÃO
# 960922                          SIM            NÃO  NÃO  SIM  NÃO
# 960923                          SIM            NÃO  NÃO  SIM  NÃO
# 960924                          SIM            NÃO  NÃO  SIM  NÃO
# 960925                          SIM            NÃO  NÃO  SIM  NÃO
# 960926                          SIM            NÃO  NÃO  SIM  NÃO
# 960927                          SIM            NÃO  NÃO  SIM  NÃO
# 960928                          SIM            NÃO  NÃO  SIM  NÃO
# 960929                          SIM            NÃO  NÃO  SIM  NÃO
# 960930                          SIM            NÃO  NÃO  SIM  NÃO
# 960931                          SIM            NÃO  NÃO  SIM  NÃO
# 960932                          SIM            NÃO  NÃO  SIM  NÃO
# 960933                          SIM            NÃO  NÃO  SIM  NÃO
# 960934                          SIM            NÃO  NÃO  SIM  NÃO
# 960935                          SIM            NÃO  NÃO  SIM  NÃO
# 960936                          SIM            NÃO  NÃO  SIM  NÃO
# 960937                          SIM            NÃO  NÃO  SIM  NÃO
# 960938                          SIM            NÃO  NÃO  SIM  NÃO
#
#        fabrica_racao identificacao_individual regua_de_manejo  bpa  \
# 960919           SIM                      SIM             SIM  NÃO
# 960920           SIM                      SIM             SIM  NÃO
# 960921           SIM                      SIM             SIM  NÃO
# 960922           SIM                      SIM             SIM  NÃO
# 960923           SIM                      SIM             SIM  NÃO
# 960924           SIM                      SIM             SIM  NÃO
# 960925           SIM                      SIM             SIM  NÃO
# 960926           SIM                      SIM             SIM  NÃO
# 960927           SIM                      SIM             SIM  NÃO
# 960928           SIM                      SIM             SIM  NÃO
# 960929           SIM                      SIM             SIM  NÃO
# 960930           SIM                      SIM             SIM  NÃO
# 960931           SIM                      SIM             SIM  NÃO
# 960932           SIM                      SIM             SIM  NÃO
# 960933           SIM                      SIM             SIM  NÃO
# 960934           SIM                      SIM             SIM  NÃO
# 960935           SIM                      SIM             SIM  NÃO
# 960936           SIM                      SIM             SIM  NÃO
# 960937           SIM                      SIM             SIM  NÃO
# 960938           SIM                      SIM             SIM  NÃO
#
#        participa_aliancas_mercadologicas rastreamento_sisbov  tot1m_chuva  \
# 960919                               SIM                 NÃO        84.77
# 960920                               SIM                 NÃO        84.77
# 960921                               SIM                 NÃO        84.77
# 960922                               SIM                 NÃO        84.77
# 960923                               SIM                 NÃO        84.77
# 960924                               SIM                 NÃO        84.77
# 960925                               SIM                 NÃO        84.77
# 960926                               SIM                 NÃO        84.77
# 960927                               SIM                 NÃO        84.77
# 960928                               SIM                 NÃO        84.77
# 960929                               SIM                 NÃO        84.77
# 960930                               SIM                 NÃO        84.77
# 960931                               SIM                 NÃO        84.77
# 960932                               SIM                 NÃO        84.77
# 960933                               SIM                 NÃO        84.77
# 960934                               SIM                 NÃO        84.77
# 960935                               SIM                 NÃO        84.77
# 960936                               SIM                 NÃO        84.77
# 960937                               SIM                 NÃO        84.77
# 960938                               SIM                 NÃO        84.77
#
#         med1m_formituinst  med1m_ndvi  med1m_prer_soja  med1m_prer_milho  \
# 960919              74.01        0.57            81.19             37.83
# 960926             0.6503  2018         D              0
# 960927             0.6503  2018         D              0
# 960928             0.6503  2018         D              0
# 960929             0.6503  2018         D              0
# 960930             0.6503  2018         D              0
# 960931             0.6503  2018         D              0
# 960932             0.6503  2018         D              0
# 960933             0.6503  2018         D              0
# 960934             0.6503  2018         D              0
# 960935             0.6503  2018         D              0
# 960936             0.6503  2018         D              0
# 960937             0.6503  2018         D              0
# 960938             0.6503  2018         D              0

# %%
df.shape
# Out:
# (960939, 50)

# %%
print(df.columns.tolist())
# Out:
# ['estabelecimento_municipio', 'data_abate', 'tipificacao', 'maturidade', 'acabamento', 'peso', 'classificacao_estabelecimento', 'outros_incentivos', 'pratica_recuperacao_pastagem', 'fertiirrigacao', 'ilp', 'ilpf', 'ifp', 'fabrica_racao', 'identificacao_individual', 'regua_de_manejo', 'bpa', 'participa_aliancas_mercadologicas', 'rastreamento_sisbov', 'tot1m_chuva', 'med1m_formituinst', 'med1m_ndvi', 'med1m_prer_soja', 'med1m_prer_milho', 'med1m_prer_boi', 'tot3m_chuva', 'med3m_formituinst', 'med3m_ndvi', 'med3m_prer_soja', 'med3m_prer_milho', 'med3m_prer_boi', 'tot6m_chuva', 'med6m_formituinst', 'med6m_ndvi', 'med6m_prer_soja', 'med6m_prer_milho', 'med6m_prer_boi', 'tot12m_chuva', 'med12m_formituinst', 'med12m_ndvi', 'med12m_prer_soja', 'med12m_prer_milho', 'med12m_prer_boi', 'cnt1m_cl_ituinst', 'cnt3m_cl_ituinst', 'cnt6m_cl_ituinst', 'cnt12m_cl_ituinst', 'ano', 'categoria', 'classificacao']

# %%
categorical_attributes = list(df.select_dtypes(include=['object']).columns)

# %%
categorical_attributes
# Out:
# ['estabelecimento_municipio',
#  'data_abate',
#  'tipificacao',
#  'maturidade',
#  'acabamento',
#  'outros_incentivos',
#  'pratica_recuperacao_pastagem',
#  'fertiirrigacao',
#  'ilp',
#  'ilpf',
#  'ifp',
#  'fabrica_racao',
#  'identificacao_individual',
#  'regua_de_manejo',
#  'bpa',
#  'participa_aliancas_mercadologicas',
#  'rastreamento_sisbov',
#  'categoria']

# %% [markdown]
# ### 1. Estabelecimento Município

# %%
csv_municipios = pd.read_csv('../../dados/municipios.csv', encoding='utf-8', delimiter=',')

# %%
csv_municipios.head()
# Out:
#    NOME_MUNIC  longitude  latitude
# 0  MUNDO NOVO  -54.28166 -23.93527
# 1    PARANHOS  -55.43303 -23.89687
# 2      JAPORA  -54.40349 -23.89407
# 3    ELDORADO  -54.28003 -23.77405
# 4    IGUATEMI  -54.55860 -23.66190

# %%
df = pd.merge(df, csv_municipios, how='left', left_on='estabelecimento_municipio', right_on='NOME_MUNIC')

# %%
df.drop(['estabelecimento_municipio', 'NOME_MUNIC'], axis=1, inplace=True)
#df.index.name = 'index'

# %%
# colunas_para_conversao = ['longitude','latitude']

# %%
# for cc in colunas_para_conversao:
#    df[cc] = df[cc].str.replace(',','.').astype(float)

# %%
selecao = df[df['longitude'].isnull()]

# %%
selecao.shape
# Out:
# (0, 51)

# %% [markdown]
# ### 2. Datas

# %%
df['data_abate'] = pd.to_datetime(df['data_abate'])

# %%
df['mes'] = df['data_abate'].dt.month

# %%
df.drop(['data_abate'], axis=1, inplace=True)

# %% [markdown]
# ### 3. Tipificação

# %%
df.tipificacao.value_counts()
# Out:
# macho inteiro     472471
# femea             273654
# macho castrado    214814
# Name: tipificacao, dtype: int64

# %%
df['tipificacao'].replace(['macho inteiro'], 1, inplace=True)
df['tipificacao'].replace(['femea'], 2, inplace=True)
df['tipificacao'].replace(['macho castrado'], 3, inplace=True)

# %% [markdown]
# ### 4. Maturidade

# %%
df.maturidade.value_counts()
# Out:
# Dois dentes       388644
# Dente de leite    330645
# Quatro dentes     176134
# Seis dentes        43001
# Oito dentes        22515
# Name: maturidade, dtype: int64

# %%
df['maturidade'].replace(['Dois dentes'], 2, inplace=True)
df['maturidade'].replace(['Dente de leite'], 1, inplace=True)
df['maturidade'].replace(['Quatro dentes'], 4, inplace=True)
df['maturidade'].replace(['Seis dentes'], 6, inplace=True)
df['maturidade'].replace(['Oito dentes'], 8, inplace=True)

# %% [markdown]
# ### 5. Substituindo os valores "Não"  e "Sim" por 0 e 1.

# %%
df = df.applymap(lambda x: 0 if "Não" in str(x) else x)
df = df.applymap(lambda x: 0 if "NÃO" in str(x) else x)

# %%
df = df.applymap(lambda x: 1 if "Sim" in str(x) else x)
df = df.applymap(lambda x: 1 if "SIM" in str(x) else x)

# %%
selecao = pd.DataFrame(data = df, columns = ['possui_outros_ incentivo','pratica_recuperacao_pastagem','fertiirrigacao', 'ilp', 'ilpf','ifp','fabrica_racao','identificacao_individual','regua_de_manejo','bpa','participa_de_aliancas_mercadolog','boa_cobertura_vegetal_com_baixa','erosao_laminar_ou_em_sulco_igua','rastreamento_sisbov','lista_trace'])

# %% [markdown]
# ### 7. Acabamento

# %%
df['acabamento'].value_counts()
# Out:
# gordura mediana - acima de 3 a ata 6 mm de espessura      507970
# gordura escassa - 1 a 3 mm de espessura                   389870
# gordura uniforme - acima de 6 e ata 10 mm de espessura     58115
# magra - gordura ausente                                     4767
# gordura excessiva - acima de 10 mm de espessura              217
# Name: acabamento, dtype: int64

# %%
df['acabamento'].replace(['magra - gordura ausente'], 1, inplace=True)
df['acabamento'].replace(['gordura escassa - 1 a 3 mm de espessura'], 2, inplace=True)
df['acabamento'].replace(['gordura mediana - acima de 3 a ata 6 mm de espessura'], 3, inplace=True)
df['acabamento'].replace(['gordura uniforme - acima de 6 e ata 10 mm de espessura'], 4, inplace=True)
df['acabamento'].replace(['gordura excessiva - acima de 10 mm de espessura'], 5, inplace=True)

# %% [markdown]
# ### 8. Categoria

# %%
df.categoria.value_counts()
# Out:
# AA     332242
# AAA    203409
# BB     161431
# D      154010
# BBB     71661
# C       38186
# Name: categoria, dtype: int64

# %%
df['categoria'].replace(['AAA'], 1, inplace=True)
df['categoria'].replace(['AA'], 2, inplace=True)
df['categoria'].replace(['BBB'], 3, inplace=True)
df['categoria'].replace(['BB'], 4, inplace=True)
df['categoria'].replace(['C'], 5, inplace=True)
df['categoria'].replace(['D'], 6, inplace=True)

# %% [markdown]
# ### Resultado final

# %%
df.shape
# Out:
# (960939, 51)

# %%
categorical_attributes = list(df.select_dtypes(include=['object']).columns)

# %%
categorical_attributes
# Out:
# []

# %%
df.to_csv("dadosTransformados_v2.csv",sep=';', index = False)
