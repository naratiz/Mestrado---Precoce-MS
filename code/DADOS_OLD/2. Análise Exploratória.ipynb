# %% [markdown]
# # Análise Exploratória

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('../dados/dadosCompletos.csv', sep=';')

# %%
pd.set_option('display.max_columns',999)
pd.set_option("display.max_rows", 999)

# %%
df.sample(5)
# Out:
#         id_animal estabelecimento_municipio data_abate  \
# 18146       18147         PARAISO DAS AGUAS  10MAY2017
# 513055     513056       SANTA RITA DO PARDO  10MAY2018
# 381711     381712        RIBAS DO RIO PARDO  02FEB2018
# 273033     273034               BRASILANDIA  29NOV2017
# 272091     272092      SAO GABRIEL DO OESTE  28NOV2017
#
#         estabelecimento_identificador  identificador_lote     tipificacao  \
# 18146                            1034                6276  macho castrado
# 513055                           5137               47541           famea
# 381711                           5061               33443           famea
# 273033                           5950               25402   macho inteiro
# 272091                           1533               25309           famea
#
#             maturidade                                         acabamento  \
# 18146      Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
# 513055  Dente de leite            gordura escassa - 1 a 3 mm de espessura
# 381711     Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
# 273033     Dois dentes            gordura escassa - 1 a 3 mm de espessura
# 272091     Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
#
#          peso    motivo_desclassificacao  q_classificacao_estabel  \
# 18146   278.2               CLASSIFICADO                     30.0
# 513055  174.0  DESCLASSIFICADO PELO PESO                     26.0
# 381711  226.5               CLASSIFICADO                     21.0
# 273033  263.0               CLASSIFICADO                     21.0
# 272091  216.5               CLASSIFICADO                     21.0
#
#        q_outros_incentiv q_pratica_recuperacao_pa q_fertiirrigacao q_ilp  \
# 18146                NÃO                      SIM              NÃO   SIM
# 513055               NÃO                      SIM              NÃO   NÃO
# 381711               NÃO                      NÃO              NÃO   NÃO
# 273033               NÃO                      NÃO              NÃO   NÃO
# 272091               NÃO                      NÃO              NÃO   NÃO
#
#        q_ilpf q_ifp q_fabrica_racao q_identificacao_individual q_regua_manejo  \
# 18146     NÃO   NÃO             SIM                        SIM            SIM
# 513055    NÃO   SIM             NÃO                        SIM            SIM
# 381711    NÃO   NÃO             NÃO                        NÃO            SIM
# 273033    NÃO   NÃO             NÃO                        NÃO            SIM
# 272091    NÃO   NÃO             SIM                        SIM            NÃO
#
#        q_bpa q_aliancas_mercadolog q_qual_alianca q_cobertura_vegetal_80_area  \
# 18146    NÃO                   SIM          ASPNP                         SIM
# 513055   NÃO                   SIM           ACNB                         SIM
# 381711   NÃO                   NÃO            NaN                         SIM
# 273033   NÃO                   NÃO            NaN                         SIM
# 272091   NÃO                   SIM          ASPNP                         NaN
#
#        q_erosaoo_sulco_20_area q_sisbov q_lista_trace    data12m     data6m  \
# 18146                      NÃO      NÃO           NaN  09MAY2016  08NOV2016
# 513055                     NÃO      SIM           SIM  09MAY2017  08NOV2017
# 381711                     NÃO      NÃO           NaN  01FEB2017  03AUG2017
# 273033                     NÃO      NÃO           NaN  28NOV2016  30MAY2017
# 272091                     NaN      SIM           SIM  27NOV2016  29MAY2017
#
#            data3m     data1m     data7d  tot7d_chuva  med7d_tempinst  \
# 18146   06FEB2017  09APR2017  02MAY2017          NaN           22.61
# 513055  06FEB2018  09APR2018  02MAY2018          0.0           25.67
# 381711  01NOV2017  02JAN2018  25JAN2018          NaN             NaN
# 273033  28AUG2017  29OCT2017  21NOV2017       7065.6           25.92
# 272091  27AUG2017  28OCT2017  20NOV2017       4590.0           24.24
#
#         med7d_tempmax  med7d_tempmin  med7d_umidinst  med7d_umidmax  \
# 18146           29.00          17.31           69.14          89.33
# 513055          32.27          20.17           55.13          81.67
# 381711            NaN            NaN             NaN            NaN
# 273033          33.00          21.39           75.67          93.67
# 272091          29.97          20.33           81.15          94.67
#
#         med7d_umidmin  med7d_velventomax  med7d_formituinst  med7d_formitumax  \
# 18146           40.56              16.16              69.90             82.36
# 513055          28.67              19.08              72.90             86.52
# 381711            NaN                NaN              46.30             46.30
# 273033          46.33              10.76              75.50             89.90
# 272091          54.67              19.36              73.47             84.78
#
#         med7d_num_pixels  med7d_ndvi  med7d_evi  med7d_prer_soja  \
# 18146                NaN         NaN        NaN            69.08
# 513055           41689.0        0.50       0.27            86.24
# 381711          106541.0        0.60       0.41            71.61
# 273033           30356.0        0.65       0.42            73.92
# 272091            7475.0        0.64       0.43            73.94
#
#         med7d_prer_milho  med7d_prer_boi  tot1m_chuva  med1m_tempinst  \
# 18146              28.19          137.96          NaN           22.29
# 513055             41.07          141.73          0.0           25.61
# 381711             32.71          145.54          NaN             NaN
# 273033             30.76          142.65      12346.4           25.68
# 272091             30.94          142.05      16626.0           23.84
#
#         med1m_tempmax  med1m_tempmin  med1m_umidinst  med1m_umidmax  \
# 18146           28.44          17.67           73.50          91.16
# 513055          31.74          20.76           58.50          80.88
# 381711            NaN            NaN           85.43          98.64
# 273033          32.98          20.70           68.93          88.56
# 272091          30.00          19.42           75.02          91.16
#
#         med1m_umidmin  med1m_velventomax  med1m_formituinst  med1m_formitumax  \
# 18146           46.47              16.31              69.68             81.62
# 513055          34.16              18.88              73.21             85.55
# 381711          55.36              14.27              40.84             40.00
# 273033          41.81              12.79              74.39             88.86
# 272091          49.41              18.41              72.19             84.23
#
#         med1m_num_pixels  med1m_ndvi  med1m_evi  med1m_prer_soja  \
# 18146                NaN         NaN        NaN            67.29
# 513055           41689.0        0.54       0.30            86.29
# 381711          106541.0        0.62       0.42            71.81
# 273033           30356.0        0.61       0.40            73.74
# 272091            7475.0        0.60       0.40            73.75
#
#         med1m_prer_milho  med1m_prer_boi  tot3m_chuva  med3m_tempinst  \
# 18146              28.20          137.93       8860.8           23.26
# 513055             40.11          142.48      19514.4           25.84
# 381711             32.73          146.42          NaN             NaN
# 273033             31.84          140.75      15916.0           26.01
# 272091             31.91          140.60      22066.0           24.78
#
#         med3m_tempmax  med3m_tempmin  med3m_umidinst  med3m_umidmax  \
# 18146           29.38          19.01           73.76          90.64
# 513055          31.78          21.48           68.01          90.72
# 381711            NaN            NaN           84.68          98.60
# 273033          33.46          20.63           65.38          86.42
# 272091          32.06          19.01           59.19          79.88
#
#         med3m_umidmin  med3m_velventomax  med3m_formituinst  med3m_formitumax  \
# 18146           46.05              16.49              70.69             82.00
# 513055          42.60              17.80              74.56             87.29
# 381711          54.53              14.26              44.33             44.00
# 273033          38.71              13.17              63.90             73.19
# 272091          34.57              17.91              71.81             85.49
#
#         med3m_num_pixels  med3m_ndvi  med3m_evi  med3m_prer_soja  \
# 18146                NaN         NaN        NaN            69.62
# 513055           41689.0        0.61       0.38            81.20
# 381711          106541.0        0.60       0.40            73.20
# 273033           30356.0        0.50       0.31            71.73
# 272091            7475.0        0.50       0.32            71.70
#
#         med3m_prer_milho  med3m_prer_boi  tot6m_chuva  med6m_tempinst  \
# 18146              32.18          141.23      11863.8           23.11
# 513055             39.39          144.00      93088.2           25.78
# 381711             32.31          144.34      47250.0           24.54
# 273033             30.48          141.72      16569.2           23.80
# 272091             30.48          141.69      39882.0           22.73
#
#         med6m_tempmax  med6m_tempmin  med6m_umidinst  med6m_umidmax  \
# 18146           29.03          19.10           75.41          91.15
# 513055          31.62          21.58           70.37          92.22
# 381711          34.12          16.05           61.24          90.34
# 273033          31.49          18.29           65.31          86.35
# 272091          29.99          16.93           59.55          79.80
#
#         med6m_umidmin  med6m_velventomax  med6m_formituinst  med6m_formitumax  \
# 18146           48.73              16.50              68.64             78.74
# 513055          44.20              18.57              74.69             87.25
# 381711          30.80              12.99              54.90             62.26
# 273033          38.23              12.26              60.39             68.71
# 272091          35.03              15.19              68.89             82.03
#
#         med6m_num_pixels  med6m_ndvi  med6m_evi  med6m_prer_soja  \
# 18146                NaN         NaN        NaN            71.37
# 513055           41689.0        0.62       0.40            77.31
# 381711          106541.0        0.52       0.33            71.89
# 273033           30356.0        0.50       0.30            71.01
# 272091            7475.0        0.48       0.30            70.97
#
#         med6m_prer_milho  med6m_prer_boi  tot12m_chuva  med12m_tempinst  \
# 18146              33.25          143.17       11863.8            23.11
# 513055             35.96          144.32      174135.0            24.48
# 381711             30.69          141.92      199746.0            23.63
# 273033             28.54          135.10       54703.2            25.08
# 272091             28.51          135.03       89726.0            23.14
#
#         med12m_tempmax  med12m_tempmin  med12m_umidinst  med12m_umidmax  \
# 18146            29.03           19.10            75.41           91.15
# 513055           30.61           19.83            65.27           87.54
# 381711           32.13           17.05            70.05           94.27
# 273033           32.04           20.16            69.17           88.39
# 272091           29.85           18.14            68.49           86.03
#
#         med12m_umidmin  med12m_velventomax  med12m_formituinst  \
# 18146            48.73               16.50               68.64
# 513055           40.17               20.06               72.16
# 381711           37.53               12.18               63.12
# 273033           42.63               11.69               66.98
# 272091           43.16               13.65               70.35
#
#         med12m_formitumax  med12m_num_pixels  med12m_ndvi  med12m_evi  \
# 18146               78.74                NaN          NaN         NaN
# 513055              84.60            41689.0         0.56        0.35
# 381711              74.84           106541.0         0.55        0.34
# 273033              77.43            30356.0         0.57        0.35
# 272091              82.77             7475.0         0.55        0.35
#
#         med12m_prer_soja  med12m_prer_milho  med12m_prer_boi  cnt7d_cl_itumax  \
# 18146              71.37              33.25           143.17              1.0
# 513055             73.84              31.98           139.34              1.0
# 381711             70.93              30.21           138.69              NaN
# 273033             71.04              30.31           138.25              1.0
# 272091             71.03              30.31           138.22              1.0
#
#         cnt7d_cl_ituinst  cnt1m_cl_itumax  cnt1m_cl_ituinst  cnt3m_cl_itumax  \
# 18146                0.0           0.8750               0.0           0.9451
# 513055               0.0           1.0000               0.0           0.9787
# 381711               NaN              NaN               NaN              NaN
# 273033               0.0           1.0000               0.0           0.9661
# 272091               0.0           0.9688               0.0           0.9362
#
#         cnt3m_cl_ituinst  cnt6m_cl_itumax  cnt6m_cl_ituinst  cnt12m_cl_itumax  \
# 18146             0.0000           0.9138            0.0000            0.9138
# 513055            0.1170           0.9837            0.0870            0.8828
# 381711               NaN           0.8873            0.0423            0.9094
# 273033            0.0678           0.8942            0.0385            0.9368
# 272091            0.0000           0.7978            0.0000            0.8602
#
#         cnt12m_cl_ituinst   ano categoria  classificacao
# 18146              0.0000  2017        AA              1
# 513055             0.0490  2018         D              0
# 381711             0.0709  2018        AA              1
# 273033             0.1225  2017        BB              1
# 272091             0.0061  2017        AA              1

# %% [markdown]
# ## 1. Dimensões do data frame e tipos de dados

# %%
print('A base de dados apresenta {} registros e {} características.'.format(df.shape[0], df.shape[1]))
# Out:
# A base de dados apresenta 1061451 registros e 125 características.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061451 entries, 0 to 1061450
# Data columns (total 125 columns):
#  #    Column                         Dtype
# ---   ------                         -----
#  0    id_animal                      int64
#  1    estabelecimento_municipio      object
#  2    data_abate                     object
#  3    estabelecimento_identificador  int64
#  4    identificador_lote             int64
#  5    tipificacao                    object
#  6    maturidade                     object
#  7    acabamento                     object
#  8    peso                           float64
#  9    motivo_desclassificacao        object
#  10   q_classificacao_estabel        float64
#  11   q_outros_incentiv              object
#  12   q_pratica_recuperacao_pa       object
#  13   q_fertiirrigacao               object
#  14   q_ilp                          object
#  15   q_ilpf                         object
#  16   q_ifp                          object
#  17   q_fabrica_racao                object
#  18   q_identificacao_individual     object
#  19   q_regua_manejo                 object
#  20   q_bpa                          object
#  21   q_aliancas_mercadolog          object
#  22   q_qual_alianca                 object
#  23   q_cobertura_vegetal_80_area    object
#  24   q_erosaoo_sulco_20_area        object
#  25   q_sisbov                       object
#  26   q_lista_trace                  object
#  27   data12m                        object
#  28   data6m                         object
#  29   data3m                         object
#  30   data1m                         object
#  31   data7d                         object
#  32   tot7d_chuva                    float64
#  33   med7d_tempinst                 float64
#  34   med7d_tempmax                  float64
#  35   med7d_tempmin                  float64
#  36   med7d_umidinst                 float64
#  37   med7d_umidmax                  float64
#  38   med7d_umidmin                  float64
#  39   med7d_velventomax              float64
#  40   med7d_formituinst              float64
#  41   med7d_formitumax               float64
#  42   med7d_num_pixels               float64
#  43   med7d_ndvi                     float64
#  44   med7d_evi                      float64
#  45   med7d_prer_soja                float64
#  46   med7d_prer_milho               float64
#  47   med7d_prer_boi                 float64
#  48   tot1m_chuva                    float64
#  49   med1m_tempinst                 float64
#  50   med1m_tempmax                  float64
#  51   med1m_tempmin                  float64
#  52   med1m_umidinst                 float64
#  53   med1m_umidmax                  float64
#  54   med1m_umidmin                  float64
#  55   med1m_velventomax              float64
#  56   med1m_formituinst              float64
#  57   med1m_formitumax               float64
#  58   med1m_num_pixels               float64
#  59   med1m_ndvi                     float64
#  60   med1m_evi                      float64
#  61   med1m_prer_soja                float64
#  62   med1m_prer_milho               float64
#  63   med1m_prer_boi                 float64
#  64   tot3m_chuva                    float64
#  65   med3m_tempinst                 float64
#  66   med3m_tempmax                  float64
#  67   med3m_tempmin                  float64
#  68   med3m_umidinst                 float64
#  69   med3m_umidmax                  float64
#  70   med3m_umidmin                  float64
#  71   med3m_velventomax              float64
#  72   med3m_formituinst              float64
#  73   med3m_formitumax               float64
#  74   med3m_num_pixels               float64
#  75   med3m_ndvi                     float64
#  76   med3m_evi                      float64
#  77   med3m_prer_soja                float64
#  78   med3m_prer_milho               float64
#  79   med3m_prer_boi                 float64
#  80   tot6m_chuva                    float64
#  81   med6m_tempinst                 float64
#  82   med6m_tempmax                  float64
#  83   med6m_tempmin                  float64
#  84   med6m_umidinst                 float64
#  85   med6m_umidmax                  float64
#  86   med6m_umidmin                  float64
#  87   med6m_velventomax              float64
#  88   med6m_formituinst              float64
#  89   med6m_formitumax               float64
#  90   med6m_num_pixels               float64
#  91   med6m_ndvi                     float64
#  92   med6m_evi                      float64
#  93   med6m_prer_soja                float64
#  94   med6m_prer_milho               float64
#  95   med6m_prer_boi                 float64
#  96   tot12m_chuva                   float64
#  97   med12m_tempinst                float64
#  98   med12m_tempmax                 float64
#  99   med12m_tempmin                 float64
#  100  med12m_umidinst                float64
#  101  med12m_umidmax                 float64
#  102  med12m_umidmin                 float64
#  103  med12m_velventomax             float64
#  104  med12m_formituinst             float64
#  105  med12m_formitumax              float64
#  106  med12m_num_pixels              float64
#  107  med12m_ndvi                    float64
#  108  med12m_evi                     float64
#  109  med12m_prer_soja               float64
#  110  med12m_prer_milho              float64
#  111  med12m_prer_boi                float64
#  112  cnt7d_cl_itumax                float64
#  113  cnt7d_cl_ituinst               float64
#  114  cnt1m_cl_itumax                float64
#  115  cnt1m_cl_ituinst               float64
#  116  cnt3m_cl_itumax                float64
#  117  cnt3m_cl_ituinst               float64
#  118  cnt6m_cl_itumax                float64
#  119  cnt6m_cl_ituinst               float64
#  120  cnt12m_cl_itumax               float64
#  121  cnt12m_cl_ituinst              float64
#  122  ano                            int64
#  123  categoria                      object
#  124  classificacao                  int64
# dtypes: float64(92), int64(5), object(28)
# memory usage: 1012.3+ MB

# %% [markdown]
# <p>Resultado do dtypes: float64(92), int64(5), object(28). 97 Características numéricas e 28 categóricas.</p>

# %%
1107689

# %% [markdown]
# ### Características identificadores

# %% [markdown]
# <p style="color:#eb4c47">id_animal, estabelecimento_identificador e identificador_lote, desta forma podem ser retiradas.</p>

# %% [markdown]
# ### Característica classificadora

# %%
categorias = df.categoria.value_counts()
categorias
# Out:
# AA     366328
# AAA    224326
# BB     174592
# D      173758
# BBB     80960
# C       41487
# Name: categoria, dtype: int64

# %% [markdown]
# <figure>
#     <figcaption style='text-align:center'><h4>Quadro classificação novilho precoce</h3></figcaption>
#   <img src="quadro_classificacao.png" alt="Quadro classificação novilho precoce">
# </figure>

# %% [markdown]
# <p>Há poucos registros das categorias caracteríscas classificadoras C e BB. A categoria D, a qual desclassifica a carcaça, esta em maior quantidade se comparada com as categoias C e B.</p>

# %%
sns.catplot(x = "categoria", data = df, 
            kind="count", 
            aspect=2,
            order = categorias.index)

# %% [markdown]
# ## 2.  Visualizando principais valores estatísticos

# %%
df.describe().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab545e235235> in <module>
# ----> 1 df.describe().T
#
# NameError: name 'df' is not defined

# %%
#df.describe().T.to_csv("describe_dados.csv")

# %% [markdown]
# ### 2.1 Possíveis outliers

# %% [markdown]
# #### Dados de precipitações

# %%
def plotarBoxplot (titulo,x, dataset):
    sns.set_palette('Accent')
    sns.set_style('darkgrid')
    box_plot = sns.boxplot(x= x, data = dataset, orient = 'h')
    box_plot.figure.set_size_inches(18,8)
    box_plot.set_title(titulo, fontsize = 20)
    box_plot

# %%
plotarBoxplot ('Total de chuvas - 7 dias', 'tot7d_chuva', df )

# %% [markdown]
# <p>Quantidade de registros a acima do valor máximo:</p>

# %%
len(df.query('tot7d_chuva > 21082'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4203a2d6ba1e> in <module>
# ----> 1 len(df.query('tot7d_chuva > 21082'))
#
# NameError: name 'df' is not defined

# %%
len(df.query('tot7d_chuva > 126670'))
# Out:
# 880

# %% [markdown]
# <p>Todos registro com valor maior que 126670 correspondem a mesma data de abate:</p>

# %%
#Seleção dos dados considerados outliers
df_outlier_preceptacao =  df.query('tot7d_chuva > 126670')

# %%
df_outlier_preceptacao.data_abate.value_counts()
# Out:
# 10OCT2018    880
# Name: data_abate, dtype: int64

# %%
df_chuva = pd.DataFrame(data = df, columns = ['tot7d_chuva','tot1m_chuva','tot3m_chuva', 'tot6m_chuva', 'tot12m_chuva'])

# %%
plotarBoxplot('Total de Chuva - 12 meses','tot12m_chuva', df)

# %%
def plotarBoxplotDf (titulo, xlabel, dataset):
    sns.set_palette('Accent')
    sns.set_style('darkgrid')
    box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(dataset))
    box_plot.set_xlabel(xlabel, fontsize=14)
    box_plot.figure.set_size_inches(20,15)
    box_plot.set_title(titulo, fontsize = 20)
    box_plot

# %%
plotarBoxplotDf ('Total de precipitacao de chuva','total de chuva por período', df_chuva )

# %% [markdown]
# #### Dados do múmero de pixels

# %% [markdown]
# #### Valores repetidos

# %% [markdown]
# <p>As características med7d_num_pixels, med1m_num_pixels, med3m_num_pixels, med6m_num_pixels e med12m_num_pixels possuem os mesmo valores.</p>

# %%
df_num_pixels = pd.DataFrame(data = df, columns = ['med7d_num_pixels','med1m_num_pixels','med3m_num_pixels', 'med6m_num_pixels', 'med12m_num_pixels'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_num_pixels))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Número de Pixels', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Número de Pixels'}, xlabel='variable', ylabel='value'>

# %%
len(df.query('med7d_num_pixels > 100000'))
# Out:
# 88596

# %% [markdown]
# #### Dados Classificação ITU

# %%
df_itu = pd.DataFrame(data = df, columns = ['cnt7d_cl_ituinst','cnt1m_cl_ituinst','cnt3m_cl_ituinst', 'cnt6m_cl_ituinst', 'cnt12m_cl_ituinst'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_itu))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Classificação ITU', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Classificação ITU'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Dados EVI

# %%
df_evi = pd.DataFrame(data = df, columns = ['med7d_evi','med1m_evi','med3m_evi', 'med6m_evi', 'med12m_evi'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_evi))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('EVI', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'EVI'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### NDVI

# %%
df_ndvi = pd.DataFrame(data = df, columns = ['med7d_ndvi','med1m_ndvi','med3m_ndvi', 'med6m_ndvi', 'med12m_ndvi'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_ndvi))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('NDVI', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'NDVI'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Velocidade do Vento

# %%
df_velventomax = pd.DataFrame(data = df, columns = ['med7d_velventomax','med1m_velventomax','med3m_velventomax', 'med6m_velventomax', 'med12m_velventomax'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_velventomax))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Velocidade do vento', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Velocidade do vento'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Temperatura Mínima

# %%
df_tempmin = pd.DataFrame(data = df, columns = ['med7d_tempmin','med1m_tempmin','med3m_tempmin', 'med6m_tempmin', 'med12m_tempmin'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_tempmin))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Temperatura mínima', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Temperatura mínima'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Umidade instantânea

# %%
df_umidinst = pd.DataFrame(data = df, columns = ['med7d_umidinst','med1m_umidinst','med3m_umidinst', 'med6m_umidinst', 'med12m_umidinst'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_umidinst))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Umidade instantâne', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Umidade instantâne'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Preço do milho

# %%
df_pre_milho = pd.DataFrame(data = df, columns = ['med7d_prer_milho','med1m_prer_milho','med3m_prer_milho', 'med6m_prer_milho', 'med12m_prer_milho'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_pre_milho))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Preço do Milho', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Preço do Milho'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Preço da Soja

# %%
df_pre_soja = pd.DataFrame(data = df, columns = ['med7d_prer_soja','med1m_prer_soja','med3m_prer_soja', 'med6m_prer_soja', 'med12m_prer_soja'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_pre_soja))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Preço da Soja', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Preço da Soja'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Preço do Boi

# %%
df_pre_boi = pd.DataFrame(data = df, columns = ['med7d_prer_boi','med1m_prer_boi','med3m_prer_boi', 'med6m_prer_boi', 'med12m_prer_boi'])

# %%
box_plot = sns.boxplot(x="variable", y="value", data=pd.melt(df_pre_boi))
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Preço da Arroba do Boi', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Preço da Arroba do Boi'}, xlabel='variable', ylabel='value'>

# %%
selecao = df.query('med7d_prer_boi < 130')

# %%
selecao.peso.describe().T
# Out:
# count    51800.000000
# mean       259.031550
# std         47.478757
# min        129.500000
# 25%        218.400000
# 50%        261.600000
# 75%        292.800000
# max        559.400000
# Name: peso, dtype: float64

# %% [markdown]
# #### Dados de Peso

# %%
sns.set_style('darkgrid')
box_plot = sns.boxplot(x='peso', data = df, orient = 'h')
box_plot.figure.set_size_inches(20,12)
box_plot.set_title('Peso da carcaça', fontsize = 20)
box_plot
# Out:
# <AxesSubplot:title={'center':'Peso da carcaça'}, xlabel='peso'>

# %% [markdown]
# ## 3. Dados ausentes

# %% [markdown]
# <p>Calcular a porcentagem de valores ausentes.</p>

# %%
round(df.isnull().mean() * 100,2).sort_values(ascending=False)
# Out:
# q_qual_alianca                   67.58
# q_lista_trace                    53.84
# q_cobertura_vegetal_80_area      21.81
# q_erosaoo_sulco_20_area          21.81
# tot7d_chuva                      11.84
# tot1m_chuva                       4.83
# q_sisbov                          4.64
# q_identificacao_individual        4.64
# q_classificacao_estabel           4.64
# q_outros_incentiv                 4.64
# q_pratica_recuperacao_pa          4.64
# q_aliancas_mercadolog             4.64
# q_bpa                             4.64
# q_regua_manejo                    4.64
# q_fabrica_racao                   4.64
# cnt7d_cl_itumax                   4.39
# med7d_tempmin                     4.38
# med7d_tempmax                     4.38
# cnt7d_cl_ituinst                  4.38
# med7d_tempinst                    4.27
# med7d_umidmin                     4.26
# med7d_umidinst                    4.17
# med12m_ndvi                       4.16
# med7d_umidmax                     4.16
# med12m_num_pixels                 4.16
# med3m_num_pixels                  4.16
# med7d_ndvi                        4.16
# med7d_evi                         4.16
# med1m_num_pixels                  4.16
# med1m_ndvi                        4.16
# med1m_evi                         4.16
# med7d_num_pixels                  4.16
# med6m_ndvi                        4.16
# med12m_evi                        4.16
# med3m_ndvi                        4.16
# med3m_evi                         4.16
# med6m_num_pixels                  4.16
# med6m_evi                         4.16
# med7d_velventomax                 4.07
# cnt1m_cl_itumax                   2.65
# med1m_tempmin                     2.65
# med1m_tempmax                     2.65
# cnt1m_cl_ituinst                  2.64
# med1m_tempinst                    2.64
# med1m_umidmin                     2.11
# med1m_umidmax                     2.11
# med1m_velventomax                 2.09
# med1m_umidinst                    2.09
# tot3m_chuva                       1.63
# cnt3m_cl_ituinst                  0.49
# cnt3m_cl_itumax                   0.49
# med3m_tempmin                     0.49
# med3m_tempmax                     0.49
# med3m_tempinst                    0.49
# med3m_umidmin                     0.02
# med3m_velventomax                 0.02
# med3m_umidmax                     0.02
# med3m_umidinst                    0.02
# tot12m_chuva                      0.00
# med6m_prer_soja                   0.00
# med6m_prer_boi                    0.00
# med6m_prer_milho                  0.00
# med6m_formitumax                  0.00
# med6m_formituinst                 0.00
# id_animal                         0.00
# med12m_tempinst                   0.00
# med12m_tempmax                    0.00
# categoria                         0.00
# ano                               0.00
# cnt12m_cl_ituinst                 0.00
# cnt12m_cl_itumax                  0.00
# cnt6m_cl_ituinst                  0.00
# cnt6m_cl_itumax                   0.00
# med12m_prer_boi                   0.00
# med12m_prer_milho                 0.00
# med12m_prer_soja                  0.00
# med12m_formitumax                 0.00
# med6m_umidmin                     0.00
# med12m_formituinst                0.00
# med12m_velventomax                0.00
# med12m_umidmin                    0.00
# med12m_umidmax                    0.00
# med12m_umidinst                   0.00
# med12m_tempmin                    0.00
# med6m_velventomax                 0.00
# med1m_prer_milho                  0.00
# med6m_umidmax                     0.00
# q_fertiirrigacao                  0.00
# data1m                            0.00
# data3m                            0.00
# data6m                            0.00
# data12m                           0.00
# q_ifp                             0.00
# q_ilpf                            0.00
# q_ilp                             0.00
# motivo_desclassificacao           0.00
# med7d_formituinst                 0.00
# peso                              0.00
# acabamento                        0.00
# maturidade                        0.00
# tipificacao                       0.00
# identificador_lote                0.00
# estabelecimento_identificador     0.00
# data_abate                        0.00
# data7d                            0.00
# med7d_formitumax                  0.00
# med6m_umidinst                    0.00
# med3m_formitumax                  0.00
# med6m_tempmin                     0.00
# med6m_tempmax                     0.00
# med6m_tempinst                    0.00
# tot6m_chuva                       0.00
# med3m_prer_boi                    0.00
# med3m_prer_milho                  0.00
# med3m_prer_soja                   0.00
# med3m_formituinst                 0.00
# med7d_prer_soja                   0.00
# med1m_prer_boi                    0.00
# estabelecimento_municipio         0.00
# med1m_prer_soja                   0.00
# med1m_formitumax                  0.00
# med1m_formituinst                 0.00
# med7d_prer_boi                    0.00
# med7d_prer_milho                  0.00
# classificacao                     0.00
# dtype: float64

# %% [markdown]
# <p>Calcular a quantidade de valores ausentes.</p>

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# q_qual_alianca                   717338
# q_lista_trace                    571523
# q_erosaoo_sulco_20_area          231491
# q_cobertura_vegetal_80_area      231491
# tot7d_chuva                      125666
# tot1m_chuva                       51263
# q_sisbov                          49296
# q_aliancas_mercadolog             49296
# q_bpa                             49296
# q_classificacao_estabel           49296
# q_outros_incentiv                 49296
# q_pratica_recuperacao_pa          49296
# q_regua_manejo                    49296
# q_identificacao_individual        49296
# q_fabrica_racao                   49296
# cnt7d_cl_itumax                   46570
# cnt7d_cl_ituinst                  46519
# med7d_tempmin                     46441
# med7d_tempmax                     46441
# med7d_tempinst                    45274
# med7d_umidmin                     45223
# med7d_umidinst                    44285
# med12m_ndvi                       44204
# med12m_num_pixels                 44204
# med3m_num_pixels                  44204
# med7d_ndvi                        44204
# med7d_evi                         44204
# med1m_num_pixels                  44204
# med1m_ndvi                        44204
# med1m_evi                         44204
# med7d_num_pixels                  44204
# med12m_evi                        44204
# med6m_evi                         44204
# med6m_ndvi                        44204
# med6m_num_pixels                  44204
# med3m_evi                         44204
# med3m_ndvi                        44204
# med7d_umidmax                     44129
# med7d_velventomax                 43218
# cnt1m_cl_itumax                   28155
# med1m_tempmin                     28155
# med1m_tempmax                     28155
# cnt1m_cl_ituinst                  27986
# med1m_tempinst                    27986
# med1m_umidmin                     22361
# med1m_umidmax                     22361
# med1m_velventomax                 22192
# med1m_umidinst                    22192
# tot3m_chuva                       17344
# med3m_tempmax                      5249
# med3m_tempmin                      5249
# med3m_tempinst                     5249
# cnt3m_cl_ituinst                   5249
# cnt3m_cl_itumax                    5249
# med3m_velventomax                   180
# med3m_umidmax                       180
# med3m_umidinst                      180
# med3m_umidmin                       180
# tot12m_chuva                          0
# med6m_prer_soja                       0
# med6m_prer_boi                        0
# med6m_formitumax                      0
# med6m_formituinst                     0
# med6m_prer_milho                      0
# id_animal                             0
# med12m_tempinst                       0
# med12m_tempmax                        0
# categoria                             0
# ano                                   0
# cnt12m_cl_ituinst                     0
# cnt12m_cl_itumax                      0
# cnt6m_cl_ituinst                      0
# cnt6m_cl_itumax                       0
# med12m_prer_boi                       0
# med12m_prer_milho                     0
# med12m_prer_soja                      0
# med12m_formitumax                     0
# med6m_umidmin                         0
# med12m_formituinst                    0
# med12m_velventomax                    0
# med12m_umidmin                        0
# med12m_umidmax                        0
# med12m_umidinst                       0
# med12m_tempmin                        0
# med6m_velventomax                     0
# med1m_prer_milho                      0
# med6m_umidmax                         0
# q_fertiirrigacao                      0
# data1m                                0
# data3m                                0
# data6m                                0
# data12m                               0
# q_ifp                                 0
# q_ilpf                                0
# q_ilp                                 0
# motivo_desclassificacao               0
# med7d_formituinst                     0
# peso                                  0
# acabamento                            0
# maturidade                            0
# tipificacao                           0
# identificador_lote                    0
# estabelecimento_identificador         0
# data_abate                            0
# data7d                                0
# med7d_formitumax                      0
# med6m_umidinst                        0
# med3m_formitumax                      0
# med6m_tempmin                         0
# med6m_tempmax                         0
# med6m_tempinst                        0
# tot6m_chuva                           0
# med3m_prer_boi                        0
# med3m_prer_milho                      0
# med3m_prer_soja                       0
# med3m_formituinst                     0
# med7d_prer_soja                       0
# med1m_prer_boi                        0
# estabelecimento_municipio             0
# med1m_prer_soja                       0
# med1m_formitumax                      0
# med1m_formituinst                     0
# med7d_prer_boi                        0
# med7d_prer_milho                      0
# classificacao                         0
# dtype: int64

# %% [markdown]
# ### 3.1 Dados faltantes q_qual_alianca

# %% [markdown]
# <p>Este valor esta relacionado a característica participa de aliancas mercadolog (Sim ou Não). Temos 717.338 registros nulos para <b>q_qual_aliança</b>, sendo que 668.042 destes corresponde a <b>q_aliancas_mercadolog</b> com valor "Não". </p>

# %%
#Criando um dataframe onde a coluna q_qual_alianca possui valores nulos.
dados_faltantes = df[pd.isnull(df.q_qual_alianca)]

# %%
#Verificando que há somente o valor 'Não' para q_aliancas_mercadolog
dados_faltantes.q_aliancas_mercadolog.value_counts()
# Out:
# NÃO    668042
# Name: q_aliancas_mercadolog, dtype: int64

# %% [markdown]
# ### Dados faltantes med3m_umidinst

# %%
#Criando um dataframe onde a coluna med3m_umidinst possui valores nulos.
dados_faltantes = df[pd.isnull(df.med3m_umidinst)]

# %%
dados_faltantes.shape
# Out:
# (180, 125)

# %%
dados_faltantes.groupby("categoria").count()
# Out:
#            id_animal  estabelecimento_municipio  data_abate  \
# categoria
# AA                77                         77          77
# AAA               92                         92          92
# BB                 6                          6           6
# BBB                2                          2           2
# D                  3                          3           3
#
#            estabelecimento_identificador  identificador_lote  tipificacao  \
# categoria
# AA                                    77                  77           77
# AAA                                   92                  92           92
# BB                                     6                   6            6
# BBB                                    2                   2            2
# D                                      3                   3            3
#
#            maturidade  acabamento  peso  motivo_desclassificacao  \
# categoria
# AA                 77          77    77                       77
# AAA                92          92    92                       92
# BB                  6           6     6                        6
# BBB                 2           2     2                        2
# D                   3           3     3                        3
#
#            q_classificacao_estabel  q_outros_incentiv  \
# categoria
# AA                              14                 14
# AAA                              4                  4
# BB                               1                  1
# BBB                              0                  0
# D                                1                  1
#
#            q_pratica_recuperacao_pa  q_fertiirrigacao  q_ilp  q_ilpf  q_ifp  \
# categoria
# AA                               14                77     77      77     77
# AAA                               4                92     92      92     92
# BB                                1                 6      6       6      6
# BBB                               0                 2      2       2      2
# D                                 1                 3      3       3      3
#
#            q_fabrica_racao  q_identificacao_individual  q_regua_manejo  q_bpa  \
# categoria
# AA                      14                          14              14     14
# AAA                      4                           4               4      4
# BB                       1                           1               1      1
# BBB                      0                           0               0      0
# D                        1                           1               1      1
#
#            q_aliancas_mercadolog  q_qual_alianca  q_cobertura_vegetal_80_area  \
# categoria
# AA                            14               0                           14
# AAA                            4               0                            4
# BB                             1               0                            1
# BBB                            0               0                            0
# D                              1               0                            1
#
#            q_erosaoo_sulco_20_area  q_sisbov  q_lista_trace  data12m  data6m  \
# categoria
# AA                              14        14              0       77      77
# AAA                              4         4              0       92      92
# BB                               1         1              0        6       6
# BBB                              0         0              0        2       2
# D                                1         1              0        3       3
#
#            data3m  data1m  data7d  tot7d_chuva  med7d_tempinst  med7d_tempmax  \
# categoria
# AA             77      77      77            0               0              0
# AAA            92      92      92            0               0              0
# BB              6       6       6            0               0              0
# BBB             2       2       2            0               0              0
# D               3       3       3            0               0              0
#
#            med7d_tempmin  med7d_umidinst  med7d_umidmax  med7d_umidmin  \
# categoria
# AA                     0               0              0              0
# AAA                    0               0              0              0
# BB                     0               0              0              0
# BBB                    0               0              0              0
# D                      0               0              0              0
#
#            med7d_velventomax  med7d_formituinst  med7d_formitumax  \
# categoria
# AA                         0                 77                77
# AAA                        0                 92                92
# BB                         0                  6                 6
# BBB                        0                  2                 2
# D                          0                  3                 3
#
#            med7d_num_pixels  med7d_ndvi  med7d_evi  med7d_prer_soja  \
# categoria
# AA                        0           0          0               77
# AAA                       0           0          0               92
# BB                        0           0          0                6
# BBB                       0           0          0                2
# D                         0           0          0                3
#
#            med7d_prer_milho  med7d_prer_boi  tot1m_chuva  med1m_tempinst  \
# categoria
# AA                       77              77            0               0
# AAA                      92              92            0               0
# BB                        6               6            0               0
# BBB                       2               2            0               0
# D                         3               3            0               0
#
#            med1m_tempmax  med1m_tempmin  med1m_umidinst  med1m_umidmax  \
# categoria
# AA                     0              0               0              0
# AAA                    0              0               0              0
# BB                     0              0               0              0
# BBB                    0              0               0              0
# D                      0              0               0              0
#
#            med1m_umidmin  med1m_velventomax  med1m_formituinst  \
# categoria
# AA                     0                  0                 77
# AAA                    0                  0                 92
# BB                     0                  0                  6
# BBB                    0                  0                  2
# D                      0                  0                  3
#
#            med1m_formitumax  med1m_num_pixels  med1m_ndvi  med1m_evi  \
# categoria
# AA                       77                 0           0          0
# AAA                      92                 0           0          0
# BB                        6                 0           0          0
# BBB                       2                 0           0          0
# D                         3                 0           0          0
#
#            med1m_prer_soja  med1m_prer_milho  med1m_prer_boi  tot3m_chuva  \
# categoria
# AA                      77                77              77            0
# AAA                     92                92              92            0
# BB                       6                 6               6            0
# BBB                      2                 2               2            0
# D                        3                 3               3            0
#
#            med3m_tempinst  med3m_tempmax  med3m_tempmin  med3m_umidinst  \
# categoria
# AA                      0              0              0               0
# AAA                     0              0              0               0
# BB                      0              0              0               0
# BBB                     0              0              0               0
# D                       0              0              0               0
#
#            med3m_umidmax  med3m_umidmin  med3m_velventomax  med3m_formituinst  \
# categoria
# AA                     0              0                  0                 77
# AAA                    0              0                  0                 92
# BB                     0              0                  0                  6
# BBB                    0              0                  0                  2
# D                      0              0                  0                  3
#
#            med3m_formitumax  med3m_num_pixels  med3m_ndvi  med3m_evi  \
# categoria
# AA                       77                 0           0          0
# AAA                      92                 0           0          0
# BB                        6                 0           0          0
# BBB                       2                 0           0          0
# D                         3                 0           0          0
#
#            med3m_prer_soja  med3m_prer_milho  med3m_prer_boi  tot6m_chuva  \
# categoria
# AA                      77                77              77           77
# AAA                     92                92              92           92
# BB                       6                 6               6            6
# BBB                      2                 2               2            2
# D                        3                 3               3            3
#
#            med6m_tempinst  med6m_tempmax  med6m_tempmin  med6m_umidinst  \
# categoria
# AA                     77             77             77              77
# AAA                    92             92             92              92
# BB                      6              6              6               6
# BBB                     2              2              2               2
# D                       3              3              3               3
#
#            med6m_umidmax  med6m_umidmin  med6m_velventomax  med6m_formituinst  \
# categoria
# AA                    77             77                 77                 77
# AAA                   92             92                 92                 92
# BB                     6              6                  6                  6
# BBB                    2              2                  2                  2
# D                      3              3                  3                  3
#
#            med6m_formitumax  med6m_num_pixels  med6m_ndvi  med6m_evi  \
# categoria
# AA                       77                 0           0          0
# AAA                      92                 0           0          0
# BB                        6                 0           0          0
# BBB                       2                 0           0          0
# D                         3                 0           0          0
#
#            med6m_prer_soja  med6m_prer_milho  med6m_prer_boi  tot12m_chuva  \
# categoria
# AA                      77                77              77            77
# AAA                     92                92              92            92
# BB                       6                 6               6             6
# BBB                      2                 2               2             2
# D                        3                 3               3             3
#
#            med12m_tempinst  med12m_tempmax  med12m_tempmin  med12m_umidinst  \
# categoria
# AA                      77              77              77               77
# AAA                     92              92              92               92
# BB                       6               6               6                6
# BBB                      2               2               2                2
# D                        3               3               3                3
#
#            med12m_umidmax  med12m_umidmin  med12m_velventomax  \
# categoria
# AA                     77              77                  77
# AAA                    92              92                  92
# BB                      6               6                   6
# BBB                     2               2                   2
# D                       3               3                   3
#
#            med12m_formituinst  med12m_formitumax  med12m_num_pixels  \
# categoria
# AA                         77                 77                  0
# AAA                        92                 92                  0
# BB                          6                  6                  0
# BBB                         2                  2                  0
# D                           3                  3                  0
#
#            med12m_ndvi  med12m_evi  med12m_prer_soja  med12m_prer_milho  \
# categoria
# AA                   0           0                77                 77
# AAA                  0           0                92                 92
# BB                   0           0                 6                  6
# BBB                  0           0                 2                  2
# D                    0           0                 3                  3
#
#            med12m_prer_boi  cnt7d_cl_itumax  cnt7d_cl_ituinst  \
# categoria
# AA                      77                0                 0
# AAA                     92                0                 0
# BB                       6                0                 0
# BBB                      2                0                 0
# D                        3                0                 0
#
#            cnt1m_cl_itumax  cnt1m_cl_ituinst  cnt3m_cl_itumax  \
# categoria
# AA                       0                 0                0
# AAA                      0                 0                0
# BB                       0                 0                0
# BBB                      0                 0                0
# D                        0                 0                0
#
#            cnt3m_cl_ituinst  cnt6m_cl_itumax  cnt6m_cl_ituinst  \
# categoria
# AA                        0               77                77
# AAA                       0               92                92
# BB                        0                6                 6
# BBB                       0                2                 2
# D                         0                3                 3
#
#            cnt12m_cl_itumax  cnt12m_cl_ituinst  ano  classificacao
# categoria
# AA                       77                 77   77             77
# AAA                      92                 92   92             92
# BB                        6                  6    6              6
# BBB                       2                  2    2              2
# D                         3                  3    3              3

# %% [markdown]
# ## 4. Matriz de correlação

# %% [markdown]
# <p>Plotar o gráfico com os registros referente a média de 7 dias</p>

# %%
col_sete_d = ['estabelecimento_municipio', 'data_abate',
       'tipificacao', 'maturidade', 'acabamento', 'peso',
       'motivo_desclassificacao', 'q_classificacao_estabel',
       'q_outros_incentiv', 'q_pratica_recuperacao_pa',
       'q_fertiirrigacao', 'q_ilp', 'q_ilpf', 'q_ifp', 'q_fabrica_racao',
       'q_identificacao_individual', 'q_regua_manejo', 'q_bpa',
       'q_aliancas_mercadolog', 'q_qual_alianca',
       'q_cobertura_vegetal_80_area', 'q_erosaoo_sulco_20_area',
       'q_sisbov', 'q_lista_trace', 'data12m', 'data6m', 'data3m',
       'data1m', 'data7d', 'tot7d_chuva', 'med7d_tempinst',
       'med7d_tempmax', 'med7d_tempmin', 'med7d_umidinst',
       'med7d_umidmax', 'med7d_umidmin', 'med7d_velventomax',
       'med7d_formituinst', 'med7d_formitumax', 'med7d_num_pixels',
       'med7d_ndvi', 'med7d_evi', 'med7d_prer_soja', 'med7d_prer_milho',
       'med7d_prer_boi', 'cnt7d_cl_itumax', 'cnt7d_cl_ituinst', 'ano', 'categoria', 'classificacao']

# %%
df_resumido = pd.read_csv('../dados/dadosCompletos.csv', encoding='ISO-8859-1', sep=';', usecols=col_sete_d)

# %%
plt.figure(figsize=(20,15)) 
sns_plot = sns.heatmap(data=df_resumido.corr(),annot=True,cmap='coolwarm', square=True);
fig = sns_plot.get_figure()
fig.savefig("Matriz_Corr_resumido.png")
