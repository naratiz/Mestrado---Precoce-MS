# %% [markdown]
# ## Converter dados para float

# %%
import pandas as pd

# %%
df = pd.read_csv('./dados/dadosCompletos.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4620ca2e4ae7> in <module>
# ----> 1 df = pd.read_csv('./dados/dadosCompletos.csv', sep=';')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './dados/dadosCompletos.csv'

# %%
#lendo algumas colunas selecionadas em colunas colunas =['cc1, 'cc2']
#df_coluns = pd.read_csv('./dados/dadosCompletos.csv', encoding='utf-8', sep=';', usecols=colunas )

# %%
pd.set_option('display.max_columns',999)
pd.set_option("display.max_rows", 999)

# %%
#df.info(verbose=True)

# %%
#df.columns.values

# %%
df.sample(5)
# Out:
#         id_animal estabelecimento_municipio data_abate  \
# 590931     590932                    TACURU  28JUN2018
# 434838     434839                   CAMAPUA  21MAR2018
# 17372       17373      SAO GABRIEL DO OESTE  09MAY2017
# 319883     319884             LAGUNA CARAPA  20DEC2017
# 150517     150518      SAO GABRIEL DO OESTE  26SEP2017
#
#         estabelecimento_identificador  identificador_lote     tipificacao  \
# 590931                           4777               54032  macho castrado
# 434838                           1843               40782           famea
# 17372                            1027                6238   macho inteiro
# 319883                           1135               27951           famea
# 150517                           4184               20125   macho inteiro
#
#             maturidade                                         acabamento  \
# 590931   Quatro dentes            gordura escassa - 1 a 3 mm de espessura
# 434838  Dente de leite  gordura mediana - acima de 3 a ata 6 mm de esp...
# 17372      Dois dentes  gordura mediana - acima de 3 a ata 6 mm de esp...
# 319883  Dente de leite  gordura mediana - acima de 3 a ata 6 mm de esp...
# 150517     Dois dentes            gordura escassa - 1 a 3 mm de espessura
#
#          peso motivo_desclassificacao  q_classificacao_estabel  \
# 590931  284.5            CLASSIFICADO                     21.0
# 434838  227.6            CLASSIFICADO                     21.0
# 17372   278.5            CLASSIFICADO                     30.0
# 319883  242.5            CLASSIFICADO                     26.0
# 150517  295.6            CLASSIFICADO                     26.0
#
#        q_outros_incentiv q_pratica_recuperacao_pa q_fertiirrigacao q_ilp  \
# 590931               NÃO                      NÃO              NÃO   NÃO
# 434838               NÃO                      NÃO              NÃO   NÃO
# 17372                NÃO                      SIM              NÃO   SIM
# 319883               NÃO                      SIM              NÃO   SIM
# 150517               NÃO                      NÃO              NÃO   NÃO
#
#        q_ilpf q_ifp q_fabrica_racao q_identificacao_individual q_regua_manejo  \
# 590931    NÃO   NÃO             SIM                        SIM            NÃO
# 434838    NÃO   NÃO             SIM                        SIM            SIM
# 17372     NÃO   NÃO             SIM                        SIM            SIM
# 319883    NÃO   NÃO             SIM                        SIM            SIM
# 150517    NÃO   NÃO             NÃO                        SIM            SIM
#
#        q_bpa q_aliancas_mercadolog q_qual_alianca q_cobertura_vegetal_80_area  \
# 590931   NÃO                   NÃO            NaN                         NaN
# 434838   NÃO                   NÃO            NaN                         SIM
# 17372    NÃO                   SIM          ASPNP                         SIM
# 319883   NÃO                   NÃO            NaN                         SIM
# 150517   NÃO                   SIM          ASPNP                         SIM
#
#        q_erosaoo_sulco_20_area q_sisbov q_lista_trace    data12m     data6m  \
# 590931                     NaN      SIM           SIM  27JUN2017  27DEC2017
# 434838                     NÃO      NÃO           NaN  20MAR2017  19SEP2017
# 17372                      NÃO      NÃO           NaN  08MAY2016  07NOV2016
# 319883                     NÃO      SIM           SIM  19DEC2016  20JUN2017
# 150517                     NÃO      SIM           NÃO  25SEP2016  27MAR2017
#
#            data3m     data1m     data7d  tot7d_chuva  med7d_tempinst  \
# 590931  27MAR2018  28MAY2018  20JUN2018          NaN           19.52
# 434838  18DEC2017  18FEB2018  13MAR2018       5464.8           25.50
# 17372   05FEB2017  08APR2017  01MAY2017       1558.2           22.63
# 319883  18SEP2017  19NOV2017  12DEC2017       1393.8           26.48
# 150517  25JUN2017  26AUG2017  18SEP2017          0.0           26.52
#
#         med7d_tempmax  med7d_tempmin  med7d_umidinst  med7d_umidmax  \
# 590931          25.90          15.20           77.00          90.89
# 434838          31.38          21.04           79.58          95.11
# 17372           28.72          18.00           78.31          93.78
# 319883          32.02          21.56           68.85          86.67
# 150517          35.03          18.90           34.89          58.56
#
#         med7d_umidmin  med7d_velventomax  med7d_formituinst  med7d_formitumax  \
# 590931          52.33              11.92              65.54             77.15
# 434838          50.11              13.24              75.33             87.35
# 17372           52.67               7.16              70.69             82.51
# 319883          47.67               4.28              75.56             86.98
# 150517          14.78              13.56              71.62             86.21
#
#         med7d_num_pixels  med7d_ndvi  med7d_evi  med7d_prer_soja  \
# 590931            8981.0        0.59       0.34            84.42
# 434838           58472.0        0.64       0.41            78.84
# 17372             7475.0        0.63       0.40            69.02
# 319883             288.0        0.63       0.47            74.29
# 150517            7475.0        0.43       0.27            70.64
#
#         med7d_prer_milho  med7d_prer_boi  tot1m_chuva  med1m_tempinst  \
# 590931             37.79          139.01        386.4           16.56
# 434838             42.06          145.05       5623.2           24.11
# 17372              28.19          138.04       1558.2           22.26
# 319883             32.50          145.86      30966.6           25.05
# 150517             29.97          142.13        121.0           26.25
#
#         med1m_tempmax  med1m_tempmin  med1m_umidinst  med1m_umidmax  \
# 590931          21.88          12.91           78.62          91.19
# 434838          30.04          20.35           81.39          95.56
# 17372           28.41          17.87           78.98          93.25
# 319883          30.52          20.70           74.31          90.31
# 150517          34.85          18.38           36.40          62.19
#
#         med1m_umidmin  med1m_velventomax  med1m_formituinst  med1m_formitumax  \
# 590931          57.63              14.48              60.89             70.31
# 434838          54.31              14.79              73.28             85.08
# 17372           54.03               8.78              70.13             81.89
# 319883          52.66               3.69              73.98             85.02
# 150517          15.38              13.98              71.48             86.70
#
#         med1m_num_pixels  med1m_ndvi  med1m_evi  med1m_prer_soja  \
# 590931            8981.0        0.58       0.35            85.00
# 434838           58472.0        0.62       0.40            78.35
# 17372             7475.0        0.63       0.40            67.18
# 319883             288.0        0.64       0.45            74.35
# 150517            7475.0        0.40       0.25            70.20
#
#         med1m_prer_milho  med1m_prer_boi  tot3m_chuva  med3m_tempinst  \
# 590931             41.27          138.92      20221.6           19.53
# 434838             39.75          145.40      16130.4           24.04
# 17372              28.20          137.95       8745.0           23.71
# 319883             31.53          143.88      86567.1           24.48
# 150517             28.58          143.43      10430.2           22.65
#
#         med3m_tempmax  med3m_tempmin  med3m_umidinst  med3m_umidmax  \
# 590931          25.55          15.27           73.85          90.03
# 434838          29.88          20.46           81.19          95.15
# 17372           29.85          19.64           78.26          92.95
# 319883          31.23          19.41           67.82          86.78
# 150517          30.49          15.91           47.62          70.24
#
#         med3m_umidmin  med3m_velventomax  med3m_formituinst  med3m_formitumax  \
# 590931          49.83              14.46              61.65             70.68
# 434838          54.84              13.67              71.95             82.68
# 17372           51.52              11.75              72.04             83.56
# 319883          43.36              10.23              72.35             85.47
# 150517          25.17              13.58              67.62             81.10
#
#         med3m_num_pixels  med3m_ndvi  med3m_evi  med3m_prer_soja  \
# 590931            8981.0        0.62       0.38            85.25
# 434838           58472.0        0.61       0.40            74.60
# 17372             7475.0        0.65       0.42            69.63
# 319883             288.0        0.56       0.37            72.77
# 150517            7475.0        0.41       0.25            70.64
#
#         med3m_prer_milho  med3m_prer_boi  tot6m_chuva  med6m_tempinst  \
# 590931             41.10          140.91      78761.2           21.54
# 434838             35.46          145.81      39600.0           24.17
# 17372              32.24          141.29      40926.6           23.75
# 319883             31.37          141.91     101717.1           23.01
# 150517             27.10          132.89      18682.4           22.40
#
#         med6m_tempmax  med6m_tempmin  med6m_umidinst  med6m_umidmax  \
# 590931          27.54          17.48           76.07          91.35
# 434838          30.41          19.97           75.18          90.96
# 17372           29.80          19.75           79.26          93.58
# 319883          29.98          17.46           62.34          82.16
# 150517          29.29          16.77           62.05          80.83
#
#         med6m_umidmin  med6m_velventomax  med6m_formituinst  med6m_formitumax  \
# 590931          51.48              14.57              61.87             69.81
# 434838          49.22              15.94              72.08             83.78
# 17372           53.06              11.73              72.27             83.78
# 319883          38.52              14.09              69.64             82.59
# 150517          38.30              11.55              68.52             80.69
#
#         med6m_num_pixels  med6m_ndvi  med6m_evi  med6m_prer_soja  \
# 590931            8981.0        0.65       0.44            80.31
# 434838           58472.0        0.56       0.37            73.70
# 17372             7475.0        0.64       0.42            71.39
# 319883             288.0        0.50       0.32            71.68
# 150517            7475.0        0.51       0.31            69.31
#
#         med6m_prer_milho  med6m_prer_boi  tot12m_chuva  med12m_tempinst  \
# 590931             38.65          143.18      211618.4            22.11
# 434838             33.43          143.79       60904.8            23.22
# 17372              33.31          143.24       40926.6            23.75
# 319883             29.11          136.80      205131.0            23.15
# 150517             27.50          133.82       48279.0            22.92
#
#         med12m_tempmax  med12m_tempmin  med12m_umidinst  med12m_umidmax  \
# 590931           28.43           17.31            69.17           87.10
# 434838           29.74           18.39            69.60           86.69
# 17372            29.80           19.75            79.26           93.58
# 319883           29.56           18.24            69.66           87.47
# 150517           29.65           17.86            68.02           85.39
#
#         med12m_umidmin  med12m_velventomax  med12m_formituinst  \
# 590931           45.72               16.71               65.50
# 434838           44.61               13.68               70.33
# 17372            53.06               11.73               72.27
# 319883           45.91               14.74               70.55
# 150517           42.94               12.21               69.96
#
#         med12m_formitumax  med12m_num_pixels  med12m_ndvi  med12m_evi  \
# 590931              75.61             8981.0         0.60        0.40
# 434838              82.21            58472.0         0.53        0.33
# 17372               83.78             7475.0         0.64        0.42
# 319883              82.81              288.0         0.57        0.36
# 150517              82.27             7475.0         0.55        0.35
#
#         med12m_prer_soja  med12m_prer_milho  med12m_prer_boi  cnt7d_cl_itumax  \
# 590931             76.05              33.95           140.28           0.5556
# 434838             71.45              30.48           138.74           1.0000
# 17372              71.39              33.31           143.24           1.0000
# 319883             71.26              30.41           138.65           1.0000
# 150517             70.71              30.05           137.63           1.0000
#
#         cnt7d_cl_ituinst  cnt1m_cl_itumax  cnt1m_cl_ituinst  cnt3m_cl_itumax  \
# 590931               0.0           0.3125               0.0           0.5263
# 434838               0.0           0.9063               0.0           0.9438
# 17372                0.0           0.8438               0.0           0.9239
# 319883               0.0           0.9375               0.0           0.9043
# 150517               0.0           1.0000               0.0           0.7849
#
#         cnt3m_cl_ituinst  cnt6m_cl_itumax  cnt6m_cl_ituinst  cnt12m_cl_itumax  \
# 590931            0.0000           0.6875            0.0000            0.7138
# 434838            0.0000           0.9330            0.0000            0.8552
# 17372             0.0108           0.9449            0.0156            0.9449
# 319883            0.0106           0.7663            0.0054            0.7712
# 150517            0.0000           0.7790            0.0055            0.8496
#
#         cnt12m_cl_ituinst   ano categoria  classificacao
# 590931             0.0032  2018         C              1
# 434838             0.0028  2018       AAA              1
# 17372              0.0156  2017        AA              1
# 319883             0.0113  2017       AAA              1
# 150517             0.0075  2017        BB              1

# %%
df.acabamento.value_counts()
# Out:
# gordura mediana - acima de 3 a ata 6 mm de espessura      565151
# gordura escassa - 1 a 3 mm de espessura                   424250
# gordura uniforme - acima de 6 e ata 10 mm de espessura     66437
# magra - gordura ausente                                     5357
# gordura excessiva - acima de 10 mm de espessura              256
# Name: acabamento, dtype: int64

# %%
#df.query('estabelecimento_identificador == 5209')

# %%
#transformar para tipo data
#df['data_abate'] = df['data_abate'].astype('datetime64')
